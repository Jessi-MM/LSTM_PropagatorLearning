# %%
import torch
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.sampler import SequentialSampler
from torch.utils.data import Dataset
import numpy as np
from matplotlib import pyplot as plt
from scipy import integrate

import matplotlib.colors as mcolors
from matplotlib import rcParams

import os
#-----
from torch.utils.tensorboard import SummaryWriter

# Enable interactive plot
# %matplotlib notebook
#plt.style.use('seaborn')

# %%
from matplotlib import rc

rc('text', usetex=True)
rc('font',**{'family':'serif','serif':['Palatino']})

color1 = ['#ff595e','#ffca3a','#8ac926','#1982c4','#6a4c93']
color = ['#83b692','#f9ada0', '#f9627d', '#c65b7c', '#5b3758']

# %% [markdown]
# ## Loading dataset

# %%
class Propagator_Dataset(Dataset):
    
    def __init__(self, data, targets, sequence_len, total_data = 4700*200, transform=True, traj=200):
        
        self.data = data
        self.targets = targets
        self.transform = transform
        self.sequence_len = sequence_len
        self.total_data = total_data//sequence_len
        self.traj = traj
        
        self.denom = self.traj//self.sequence_len  # 0-199=200 data per file / 5 = seq len 
        
    def __getitem__(self, index):
        
        total_data = self.total_data  # 200 data by file (from 0 to 199), 1000 files(from 0 to 999), total data: 200*100 = 200000
        
        if index > total_data:
            print("Error, this data does not exist")
        else:
            index_data = (index//self.denom)%self.denom  # because there 0-199=200 data per file / 5 = seq len 
            index_t = (index*self.sequence_len-self.traj)%self.traj
            
            X = np.empty((self.sequence_len,96), np.float32)
            y = np.empty((self.sequence_len,64), np.float32)
            
            for i in range(self.sequence_len):
                # Input data: Wavepacket real and imaginary part + Potential at time t
                x_r = (np.load(self.data+str(index_data)+'/Wavepacket/'+str(index_t+i)+'-wave.npy')).real
                x_i = (np.load(self.data+str(index_data)+'/Wavepacket/'+str(index_t+i)+'-wave.npy')).imag
                x_p = np.load(self.data+str(index_data)+'/Potential/'+str(index_t+i)+'-potential.npy')
                
                X[i] = np.concatenate((x_r, x_i, x_p))  # flat array form
                
                # Output data: Wavepacket real and imaginary part at time t+1
                y_r = (np.load(self.targets+str(index_data)+'/Wavepacket/'+str(index_t+i+1)+'-wave.npy')).real
                y_i = (np.load(self.targets+str(index_data)+'/Wavepacket/'+str(index_t+i+1)+'-wave.npy')).imag
        
                y[i] = np.concatenate((y_r, y_i))  # flat array form
                
            '''  
            # Output data: Wavepacket real and imaginary part at time t+sequence len
            y_r = (np.load(self.targets+str(index_data)+'/Wavepacket/'+str(index_t+self.sequence_len)+'-wave.npy')).real
            y_i = (np.load(self.targets+str(index_data)+'/Wavepacket/'+str(index_t+self.sequence_len)+'-wave.npy')).imag
        
            y = np.concatenate((y_r, y_i))  # flat array form
            '''  
        
            if self.transform:
                X = torch.from_numpy(X)
                y = torch.from_numpy(y)
        
            return X, y#[None, :]
    
    def __len__(self):
        
        
        return self.total_data

# %%
path = '../../Data_Gaussian/data'  # Directory where are saving our data
seq_len = 5  # How many time stamps

# %% [markdown]
# ![Ejemplo](img/example_seq_len.png)

# %%
dataset = Propagator_Dataset(data=path, targets=path, transform=True, sequence_len=seq_len)

# %%
dataset_size = len(dataset)
print('Total of data ', dataset_size)
# Out:
# Total of data  188000

# %% [markdown]
# ## Training and Validation data split

# %%
test_split = 0.1
validation_split = 0.2  
shuffle_dataset = True
random_seed= 42

# %%
# Creating data indices for training and validation splits:
indices = list(range(dataset_size))
split_val = int(np.floor(validation_split * dataset_size))
split_test = int(np.floor(test_split * dataset_size))

if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
    

test_indices = indices[0:split_test] 
val_indices = indices[split_test:split_test+split_val]   
train_indices = indices[split_test+split_val:]

#train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)
test_sampler = SubsetRandomSampler(test_indices)


# Creating PT data samplers and loaders: Sequential form:
#train_sampler = SequentialSampler(train_indices)
#test_sampler = SequentialSampler(val_indices)

# %%
train_sampler

# %%
print(f"Total of train samples: {len(train_sampler)}")
print(f"Total of validation samples: {len(val_sampler)}")
print(f"Total of test samples: {len(test_sampler)}")
# Out:
# Total of train samples: 131600
# Total of validation samples: 37600
# Total of test samples: 18800

# %%
batch_size = 20

# %%
train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)
test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)

# %%
train_loader

# %% [markdown]
# ## Shape of data

# %%
for X, y in train_loader:
    print("Train data:")
    print(f"Shape of X in train loader: {X.shape}")
    print(f"Shape of y in train loader: {y.shape}")
    print(f"Batch size: {X.size(0)}")
    break
# Out:
# Train data:
# Shape of X in train loader: torch.Size([20, 5, 96])
# Shape of y in train loader: torch.Size([20, 5, 64])
# Batch size: 20

# %% [markdown]
# ## Visualization

# %%
# Display features and label.
train_features, train_labels = next(iter(train_loader))

X_vis = train_features[0].squeeze()
y_vis = train_labels[0].squeeze()

# %%
r_n = np.linspace(-1.5,1.5,32)

In_real_vis = X_vis[4,0:32].detach().numpy()
In_imag_vis = X_vis[4,32:64].detach().numpy()
In_pote = X_vis[4,64:96].detach().numpy()

Ou_real_vis = y_vis[4,0:32].detach().numpy()
Ou_imag_vis = y_vis[4,32:64].detach().numpy()


fig, axs = plt.subplots(2,1)

# Lenght: au -> Angstroms
axs[0].plot(r_n, In_pote*(1/1.5936e-3), "-", label="V(r,t)", color=color[3])
axs[0].plot(r_n, In_real_vis*30, label="$\psi_{real}(r, t)$", color = color[0])  # Escaled
axs[0].plot(r_n, In_imag_vis*30, label="$\psi_{imag}(r, t)$", color=color[1])  # Escaled
axs[0].set_title("Entrada")

axs[1].plot(r_n, Ou_real_vis*30, label="$\psi_{real}(r, t+1)$", color = color[0])  # Escaled
axs[1].plot(r_n, Ou_imag_vis*30, label="$\psi_{imag}(r, t+1)$", color = color[1])  # Escaled
axs[1].set_title("Salida")

for axr1 in axs:
    axr1.set_ylim([-15, 60])
    axr1.legend()
    axr1.set(xlabel='Position [$\AA$]', ylabel='Energy [Kcal/mol]')
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

plt.gcf().set_size_inches(6, 8)
ax.legend()
plt.show()

# %% [markdown]
# ## LSTM model
# ___

# %%
device = 'cpu'

# %%
class LSTM(nn.Module):
    def __init__(self, num_output, input_size, hidden_size, num_layers, seq_length):
        super(LSTM, self).__init__()
        self.num_output = num_output  # number of output
        self.num_layers = num_layers  # number of layers
        self.input_size = input_size  # input size
        self.hidden_size = hidden_size  # hidden state
        self.seq_length = seq_length  # sequence length

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                          num_layers=num_layers, batch_first=True) #lstm
        
        #self.fc_1 =  nn.Linear(hidden_size, 1024) #fully connected 1

        #self.relu = nn.ReLU()
        
        self.fc = nn.Linear(hidden_size, num_output) #fully connected last layer
    
    def forward(self,x):
        
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #hidden state
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #internal state
        
        # Propagate input through LSTM
        output, (hn, cn) = self.lstm(x, (h_0, c_0)) #lstm with input, hidden, and internal state
        #hn = hn.view(-1,self.hidden_size) #reshaping the data for Dense layer next
        #out = self.relu(hn)
        #out = self.fc_1(out) #first Dense
        #out = self.relu(output) #relu
        out = self.fc(output) #Final Output
        return out

# %%
input_size = 96  # number of features: 32 real part +32 complex part +32 potential
hidden_size = 512  # number of features in hidden state
num_layers = 1  # number of stacked lstm layers

num_output = 64  # number of output: 32 real part + 32 complex part
sequence_len = seq_len # lenght of time steps (1 fs each one) total 5 fs

learning_rate = 1e-4

# %%
model = LSTM(num_output, input_size, hidden_size, num_layers, sequence_len) #our lstm class

# %%
# Initialize the loss function and optimizer
criterion = nn.MSELoss().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)  #weight_decay=0.01 <- default

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(96, 512, batch_first=True)
#   (fc): Linear(in_features=512, out_features=64, bias=True)
# )

# %% [markdown]
# ## Accuracy function

# %%
def S_overlap(Psi_true, Psi_ANN):
    """
    Input:
    Psi_true: Evolution of wavepacket from dataset test, Shape: (batch size, sequence lenght, 64)
    Psi_ANN: Evolution of wavepacket predicted with the model, Shape: (batch size, sequence lenght, 64)
    
    Output:
    S: Absolute magnitude
    angle: phase
    Characterizes the quality of the predictions. See equation (11) of Main article
    
    """
    S_tot = []
    angle_tot = []
    for j in range(batch_size):
        for l in range(seq_len):
            Psi_true_re = Psi_true[j,l,0:32]  # real part of wavepacket
            Psi_true_im = Psi_true[j,l,32:64]  # imaginary part of wavepacket
            Psi_t = torch.view_as_complex(torch.stack((Psi_true_re,Psi_true_im), -1))
    
    
            Psi_ANN_re = Psi_ANN[j,l,0:32]  # realpart of wavepacket predicted
            Psi_ANN_im = -Psi_ANN[j,l,32:64]  # imaginary part of wavepacket predicted (- because conjugate)
            Psi_A = torch.view_as_complex(torch.stack((Psi_ANN_re,Psi_ANN_im), -1))
        
        
        
            overlap = []
            for i in range(32):
                overlap.append(torch.tensor([Psi_A[i]*Psi_t[i]]))
            overl = torch.tensor(overlap)
        
            # Integrate over r (real integral + complex integral)
            # Simpson method in the grid r_n (angstroms -> au)
            r_n = np.linspace(-1.5,1.5,32)*(1/0.5291775)
            overl_real = overl.real.numpy()
            overl_imag = overl.imag.numpy()
    
            real_integ = integrate.simpson(overl_real, r_n)
            imag_integ = integrate.simpson(overl_imag, r_n)
    
            # Covert to phase and magnitude of the complex result
            S_tot.append(np.sqrt(real_integ**2 + imag_integ**2))
            angle_tot.append(np.arctan(imag_integ/real_integ))
        
    S = sum(S_tot)/(batch_size*seq_len)
    angle = sum(angle_tot)/(batch_size*seq_len)
    
    return S, angle

# %%
# Test over test loader
correct1 = 0
for X, y in test_loader:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
    X, y = X.to(device), y.to(device)
    S, angle = S_overlap(y, y)  # Accuracy by equation (11) Main Article       
    correct1 += S
correct1 /= len(test_loader)
print(f"Test Error: \n Accuracy: {(100*correct1):>0.1f}%\n")  # Should be 100% because y=y => main of |S| = 1

# %%
writer = SummaryWriter(comment="1LSTM_512neu_BATCH_20_LR_1E-4_4700DATA")  # To use tensorboard

# %%
for X,y in train_loader:
    writer.add_graph(model,X)  # to draw diagram model
    break

# %% [markdown]
# ## Train & Test loop definition

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader)#len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.squeeze().to(device)

        # Compute prediction error
        pred = model(X.float()).squeeze()
        loss = loss_fn(pred, y.float())
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    writer.add_scalar("Loss/train", loss.item(), epoch)

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correctS, correct_phase = 0, 0, 0
    
    with torch.no_grad():
        for X, y in dataloader:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
            X, y = X.to(device), y.to(device)
            pred = model(X.float())
            test_loss += loss_fn(pred, y).item()
            S, angle = S_overlap(y, pred)  
            correctS += S
            correct_phase += angle
    
    correctS /= num_batches
    correct_phase /= num_batches
    test_loss /= num_batches
    
    writer.add_scalar('Accuracy Magnitude |S| /test', 100*correctS, epoch)  # Should be 100%
    writer.add_scalar('Accuracy phase /test', correct_phase, epoch)  # Should be 0
    writer.add_scalar("Loss/validation", test_loss, epoch)

    

    print(f"Test Error: \n Accuracy Magnitude |S|: {(100*correctS):>0.1f}%")
    print(f"Test Error: \n Accuracy phase: {(correct_phase):>0.1f}\n")

# %% [markdown]
# ## Training

# %%
epochs = 10
for epoch in range(0,epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train(train_loader, model, criterion, optimizer)
    test(val_loader, model, criterion)
    
writer.flush()
# Out:
# Epoch 1
# -------------------------------
# loss: 0.086157  [    0/ 6580]
# loss: 0.078790  [  100/ 6580]
# loss: 0.069838  [  200/ 6580]
# loss: 0.073538  [  300/ 6580]
# loss: 0.059319  [  400/ 6580]
# loss: 0.065854  [  500/ 6580]
# loss: 0.061635  [  600/ 6580]
# loss: 0.068890  [  700/ 6580]
# loss: 0.050681  [  800/ 6580]
# loss: 0.061911  [  900/ 6580]
# loss: 0.065010  [ 1000/ 6580]
# loss: 0.055256  [ 1100/ 6580]
# loss: 0.050221  [ 1200/ 6580]
# loss: 0.066801  [ 1300/ 6580]
# loss: 0.059518  [ 1400/ 6580]
# loss: 0.065734  [ 1500/ 6580]
# loss: 0.066888  [ 1600/ 6580]
# loss: 0.057241  [ 1700/ 6580]
# loss: 0.058341  [ 1800/ 6580]
# loss: 0.040573  [ 1900/ 6580]
# loss: 0.062804  [ 2000/ 6580]
# loss: 0.051070  [ 2100/ 6580]
# loss: 0.065386  [ 2200/ 6580]
# loss: 0.055916  [ 2300/ 6580]
# loss: 0.052612  [ 2400/ 6580]
# loss: 0.047135  [ 2500/ 6580]
# loss: 0.045885  [ 2600/ 6580]
# loss: 0.045462  [ 2700/ 6580]
# loss: 0.055806  [ 2800/ 6580]
# loss: 0.049502  [ 2900/ 6580]
# loss: 0.055004  [ 3000/ 6580]
# loss: 0.058278  [ 3100/ 6580]
# loss: 0.055626  [ 3200/ 6580]
# loss: 0.050163  [ 3300/ 6580]
# loss: 0.064552  [ 3400/ 6580]
# loss: 0.052733  [ 3500/ 6580]
# loss: 0.056188  [ 3600/ 6580]
# loss: 0.051109  [ 3700/ 6580]
# loss: 0.043989  [ 3800/ 6580]
# loss: 0.043376  [ 3900/ 6580]
# loss: 0.052686  [ 4000/ 6580]
# loss: 0.041481  [ 4100/ 6580]
# loss: 0.052622  [ 4200/ 6580]
# loss: 0.059715  [ 4300/ 6580]
# loss: 0.046721  [ 4400/ 6580]
# loss: 0.046456  [ 4500/ 6580]
# loss: 0.060642  [ 4600/ 6580]
# loss: 0.060281  [ 4700/ 6580]
# loss: 0.061084  [ 4800/ 6580]
# loss: 0.048603  [ 4900/ 6580]
# loss: 0.059698  [ 5000/ 6580]
# loss: 0.050807  [ 5100/ 6580]
# loss: 0.044101  [ 5200/ 6580]
# loss: 0.042934  [ 5300/ 6580]
# loss: 0.035961  [ 5400/ 6580]
# loss: 0.045624  [ 5500/ 6580]
# loss: 0.052722  [ 5600/ 6580]
# loss: 0.041520  [ 5700/ 6580]
# loss: 0.049616  [ 5800/ 6580]
# loss: 0.054107  [ 5900/ 6580]
# loss: 0.036853  [ 6000/ 6580]
# loss: 0.048974  [ 6100/ 6580]
# loss: 0.048975  [ 6200/ 6580]
# loss: 0.032508  [ 6300/ 6580]
# loss: 0.052735  [ 6400/ 6580]
# loss: 0.044814  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 48.9%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 2
# -------------------------------
# loss: 0.035649  [    0/ 6580]
# loss: 0.045734  [  100/ 6580]
# loss: 0.037830  [  200/ 6580]
# loss: 0.058847  [  300/ 6580]
# loss: 0.040046  [  400/ 6580]
# loss: 0.044291  [  500/ 6580]
# loss: 0.050786  [  600/ 6580]
# loss: 0.038115  [  700/ 6580]
# loss: 0.038473  [  800/ 6580]
# loss: 0.044089  [  900/ 6580]
# loss: 0.039503  [ 1000/ 6580]
# loss: 0.042946  [ 1100/ 6580]
# loss: 0.044164  [ 1200/ 6580]
# loss: 0.044568  [ 1300/ 6580]
# loss: 0.051873  [ 1400/ 6580]
# loss: 0.035639  [ 1500/ 6580]
# loss: 0.046851  [ 1600/ 6580]
# loss: 0.045216  [ 1700/ 6580]
# loss: 0.041831  [ 1800/ 6580]
# loss: 0.041717  [ 1900/ 6580]
# loss: 0.048237  [ 2000/ 6580]
# loss: 0.043737  [ 2100/ 6580]
# loss: 0.043140  [ 2200/ 6580]
# loss: 0.045791  [ 2300/ 6580]
# loss: 0.038165  [ 2400/ 6580]
# loss: 0.041067  [ 2500/ 6580]
# loss: 0.053532  [ 2600/ 6580]
# loss: 0.037484  [ 2700/ 6580]
# loss: 0.039583  [ 2800/ 6580]
# loss: 0.042040  [ 2900/ 6580]
# loss: 0.044157  [ 3000/ 6580]
# loss: 0.039703  [ 3100/ 6580]
# loss: 0.036659  [ 3200/ 6580]
# loss: 0.048293  [ 3300/ 6580]
# loss: 0.034281  [ 3400/ 6580]
# loss: 0.032877  [ 3500/ 6580]
# loss: 0.040114  [ 3600/ 6580]
# loss: 0.042788  [ 3700/ 6580]
# loss: 0.039966  [ 3800/ 6580]
# loss: 0.029003  [ 3900/ 6580]
# loss: 0.040870  [ 4000/ 6580]
# loss: 0.031871  [ 4100/ 6580]
# loss: 0.036852  [ 4200/ 6580]
# loss: 0.039251  [ 4300/ 6580]
# loss: 0.033167  [ 4400/ 6580]
# loss: 0.037783  [ 4500/ 6580]
# loss: 0.031712  [ 4600/ 6580]
# loss: 0.039732  [ 4700/ 6580]
# loss: 0.040119  [ 4800/ 6580]
# loss: 0.032629  [ 4900/ 6580]
# loss: 0.032568  [ 5000/ 6580]
# loss: 0.038370  [ 5100/ 6580]
# loss: 0.034543  [ 5200/ 6580]
# loss: 0.039978  [ 5300/ 6580]
# loss: 0.039861  [ 5400/ 6580]
# loss: 0.034180  [ 5500/ 6580]
# loss: 0.024262  [ 5600/ 6580]
# loss: 0.032079  [ 5700/ 6580]
# loss: 0.037730  [ 5800/ 6580]
# loss: 0.035565  [ 5900/ 6580]
# loss: 0.034714  [ 6000/ 6580]
# loss: 0.028509  [ 6100/ 6580]
# loss: 0.032638  [ 6200/ 6580]
# loss: 0.041841  [ 6300/ 6580]
# loss: 0.024616  [ 6400/ 6580]
# loss: 0.031334  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 61.2%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 3
# -------------------------------
# loss: 0.038252  [    0/ 6580]
# loss: 0.033500  [  100/ 6580]
# loss: 0.037072  [  200/ 6580]
# loss: 0.032047  [  300/ 6580]
# loss: 0.036723  [  400/ 6580]
# loss: 0.036180  [  500/ 6580]
# loss: 0.037399  [  600/ 6580]
# loss: 0.026998  [  700/ 6580]
# loss: 0.026667  [  800/ 6580]
# loss: 0.033798  [  900/ 6580]
# loss: 0.030513  [ 1000/ 6580]
# loss: 0.030830  [ 1100/ 6580]
# loss: 0.029791  [ 1200/ 6580]
# loss: 0.034151  [ 1300/ 6580]
# loss: 0.035076  [ 1400/ 6580]
# loss: 0.021138  [ 1500/ 6580]
# loss: 0.034679  [ 1600/ 6580]
# loss: 0.035097  [ 1700/ 6580]
# loss: 0.025467  [ 1800/ 6580]
# loss: 0.029740  [ 1900/ 6580]
# loss: 0.035126  [ 2000/ 6580]
# loss: 0.028534  [ 2100/ 6580]
# loss: 0.033447  [ 2200/ 6580]
# loss: 0.031781  [ 2300/ 6580]
# loss: 0.032054  [ 2400/ 6580]
# loss: 0.033099  [ 2500/ 6580]
# loss: 0.024950  [ 2600/ 6580]
# loss: 0.038808  [ 2700/ 6580]
# loss: 0.033272  [ 2800/ 6580]
# loss: 0.024568  [ 2900/ 6580]
# loss: 0.029521  [ 3000/ 6580]
# loss: 0.028520  [ 3100/ 6580]
# loss: 0.028394  [ 3200/ 6580]
# loss: 0.035801  [ 3300/ 6580]
# loss: 0.029478  [ 3400/ 6580]
# loss: 0.035019  [ 3500/ 6580]
# loss: 0.022892  [ 3600/ 6580]
# loss: 0.035669  [ 3700/ 6580]
# loss: 0.027624  [ 3800/ 6580]
# loss: 0.028716  [ 3900/ 6580]
# loss: 0.024595  [ 4000/ 6580]
# loss: 0.025162  [ 4100/ 6580]
# loss: 0.026801  [ 4200/ 6580]
# loss: 0.024422  [ 4300/ 6580]
# loss: 0.023437  [ 4400/ 6580]
# loss: 0.028836  [ 4500/ 6580]
# loss: 0.030572  [ 4600/ 6580]
# loss: 0.025952  [ 4700/ 6580]
# loss: 0.032263  [ 4800/ 6580]
# loss: 0.030553  [ 4900/ 6580]
# loss: 0.027069  [ 5000/ 6580]
# loss: 0.025362  [ 5100/ 6580]
# loss: 0.035183  [ 5200/ 6580]
# loss: 0.023586  [ 5300/ 6580]
# loss: 0.030029  [ 5400/ 6580]
# loss: 0.031953  [ 5500/ 6580]
# loss: 0.021415  [ 5600/ 6580]
# loss: 0.020501  [ 5700/ 6580]
# loss: 0.021386  [ 5800/ 6580]
# loss: 0.019935  [ 5900/ 6580]
# loss: 0.028509  [ 6000/ 6580]
# loss: 0.023355  [ 6100/ 6580]
# loss: 0.020820  [ 6200/ 6580]
# loss: 0.030046  [ 6300/ 6580]
# loss: 0.023344  [ 6400/ 6580]
# loss: 0.023146  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 70.5%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 4
# -------------------------------
# loss: 0.018557  [    0/ 6580]
# loss: 0.029658  [  100/ 6580]
# loss: 0.026930  [  200/ 6580]
# loss: 0.027228  [  300/ 6580]
# loss: 0.020443  [  400/ 6580]
# loss: 0.024111  [  500/ 6580]
# loss: 0.026863  [  600/ 6580]
# loss: 0.021724  [  700/ 6580]
# loss: 0.020856  [  800/ 6580]
# loss: 0.033813  [  900/ 6580]
# loss: 0.023359  [ 1000/ 6580]
# loss: 0.021080  [ 1100/ 6580]
# loss: 0.028061  [ 1200/ 6580]
# loss: 0.021191  [ 1300/ 6580]
# loss: 0.024675  [ 1400/ 6580]
# loss: 0.023998  [ 1500/ 6580]
# loss: 0.018551  [ 1600/ 6580]
# loss: 0.020221  [ 1700/ 6580]
# loss: 0.024265  [ 1800/ 6580]
# loss: 0.019455  [ 1900/ 6580]
# loss: 0.019479  [ 2000/ 6580]
# loss: 0.021358  [ 2100/ 6580]
# loss: 0.024789  [ 2200/ 6580]
# loss: 0.024402  [ 2300/ 6580]
# loss: 0.023351  [ 2400/ 6580]
# loss: 0.023653  [ 2500/ 6580]
# loss: 0.023096  [ 2600/ 6580]
# loss: 0.020123  [ 2700/ 6580]
# loss: 0.021806  [ 2800/ 6580]
# loss: 0.027048  [ 2900/ 6580]
# loss: 0.021483  [ 3000/ 6580]
# loss: 0.023212  [ 3100/ 6580]
# loss: 0.017539  [ 3200/ 6580]
# loss: 0.021365  [ 3300/ 6580]
# loss: 0.024772  [ 3400/ 6580]
# loss: 0.021783  [ 3500/ 6580]
# loss: 0.021275  [ 3600/ 6580]
# loss: 0.019287  [ 3700/ 6580]
# loss: 0.021793  [ 3800/ 6580]
# loss: 0.017718  [ 3900/ 6580]
# loss: 0.021290  [ 4000/ 6580]
# loss: 0.016619  [ 4100/ 6580]
# loss: 0.020482  [ 4200/ 6580]
# loss: 0.019967  [ 4300/ 6580]
# loss: 0.020619  [ 4400/ 6580]
# loss: 0.019706  [ 4500/ 6580]
# loss: 0.015343  [ 4600/ 6580]
# loss: 0.025333  [ 4700/ 6580]
# loss: 0.021151  [ 4800/ 6580]
# loss: 0.018122  [ 4900/ 6580]
# loss: 0.019231  [ 5000/ 6580]
# loss: 0.018430  [ 5100/ 6580]
# loss: 0.024338  [ 5200/ 6580]
# loss: 0.025881  [ 5300/ 6580]
# loss: 0.017530  [ 5400/ 6580]
# loss: 0.021719  [ 5500/ 6580]
# loss: 0.020252  [ 5600/ 6580]
# loss: 0.020098  [ 5700/ 6580]
# loss: 0.014383  [ 5800/ 6580]
# loss: 0.021560  [ 5900/ 6580]
# loss: 0.020972  [ 6000/ 6580]
# loss: 0.017857  [ 6100/ 6580]
# loss: 0.017011  [ 6200/ 6580]
# loss: 0.014731  [ 6300/ 6580]
# loss: 0.019992  [ 6400/ 6580]
# loss: 0.021824  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 77.6%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 5
# -------------------------------
# loss: 0.019653  [    0/ 6580]
# loss: 0.018581  [  100/ 6580]
# loss: 0.018969  [  200/ 6580]
# loss: 0.017970  [  300/ 6580]
# loss: 0.017751  [  400/ 6580]
# loss: 0.020917  [  500/ 6580]
# loss: 0.012484  [  600/ 6580]
# loss: 0.017193  [  700/ 6580]
# loss: 0.016748  [  800/ 6580]
# loss: 0.022232  [  900/ 6580]
# loss: 0.020578  [ 1000/ 6580]
# loss: 0.020166  [ 1100/ 6580]
# loss: 0.019799  [ 1200/ 6580]
# loss: 0.018650  [ 1300/ 6580]
# loss: 0.016425  [ 1400/ 6580]
# loss: 0.020176  [ 1500/ 6580]
# loss: 0.020230  [ 1600/ 6580]
# loss: 0.017719  [ 1700/ 6580]
# loss: 0.014462  [ 1800/ 6580]
# loss: 0.018112  [ 1900/ 6580]
# loss: 0.020047  [ 2000/ 6580]
# loss: 0.014559  [ 2100/ 6580]
# loss: 0.019862  [ 2200/ 6580]
# loss: 0.015393  [ 2300/ 6580]
# loss: 0.017282  [ 2400/ 6580]
# loss: 0.016867  [ 2500/ 6580]
# loss: 0.021167  [ 2600/ 6580]
# loss: 0.015261  [ 2700/ 6580]
# loss: 0.018309  [ 2800/ 6580]
# loss: 0.016806  [ 2900/ 6580]
# loss: 0.020038  [ 3000/ 6580]
# loss: 0.017978  [ 3100/ 6580]
# loss: 0.015233  [ 3200/ 6580]
# loss: 0.018700  [ 3300/ 6580]
# loss: 0.016081  [ 3400/ 6580]
# loss: 0.014157  [ 3500/ 6580]
# loss: 0.017958  [ 3600/ 6580]
# loss: 0.016258  [ 3700/ 6580]
# loss: 0.017571  [ 3800/ 6580]
# loss: 0.016973  [ 3900/ 6580]
# loss: 0.015313  [ 4000/ 6580]
# loss: 0.014277  [ 4100/ 6580]
# loss: 0.014724  [ 4200/ 6580]
# loss: 0.018450  [ 4300/ 6580]
# loss: 0.014823  [ 4400/ 6580]
# loss: 0.014777  [ 4500/ 6580]
# loss: 0.015493  [ 4600/ 6580]
# loss: 0.017680  [ 4700/ 6580]
# loss: 0.015469  [ 4800/ 6580]
# loss: 0.015240  [ 4900/ 6580]
# loss: 0.013156  [ 5000/ 6580]
# loss: 0.014696  [ 5100/ 6580]
# loss: 0.015146  [ 5200/ 6580]
# loss: 0.011237  [ 5300/ 6580]
# loss: 0.015253  [ 5400/ 6580]
# loss: 0.012430  [ 5500/ 6580]
# loss: 0.015178  [ 5600/ 6580]
# loss: 0.014327  [ 5700/ 6580]
# loss: 0.015849  [ 5800/ 6580]
# loss: 0.014253  [ 5900/ 6580]
# loss: 0.012932  [ 6000/ 6580]
# loss: 0.016544  [ 6100/ 6580]
# loss: 0.013270  [ 6200/ 6580]
# loss: 0.014037  [ 6300/ 6580]
# loss: 0.013453  [ 6400/ 6580]
# loss: 0.015568  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 82.6%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 6
# -------------------------------
# loss: 0.013529  [    0/ 6580]
# loss: 0.012107  [  100/ 6580]
# loss: 0.011391  [  200/ 6580]
# loss: 0.015395  [  300/ 6580]
# loss: 0.015227  [  400/ 6580]
# loss: 0.013004  [  500/ 6580]
# loss: 0.013994  [  600/ 6580]
# loss: 0.016556  [  700/ 6580]
# loss: 0.013787  [  800/ 6580]
# loss: 0.013927  [  900/ 6580]
# loss: 0.013840  [ 1000/ 6580]
# loss: 0.013438  [ 1100/ 6580]
# loss: 0.014588  [ 1200/ 6580]
# loss: 0.012006  [ 1300/ 6580]
# loss: 0.010889  [ 1400/ 6580]
# loss: 0.011971  [ 1500/ 6580]
# loss: 0.014789  [ 1600/ 6580]
# loss: 0.016145  [ 1700/ 6580]
# loss: 0.016197  [ 1800/ 6580]
# loss: 0.013076  [ 1900/ 6580]
# loss: 0.012511  [ 2000/ 6580]
# loss: 0.013108  [ 2100/ 6580]
# loss: 0.013121  [ 2200/ 6580]
# loss: 0.013504  [ 2300/ 6580]
# loss: 0.014229  [ 2400/ 6580]
# loss: 0.013883  [ 2500/ 6580]
# loss: 0.011507  [ 2600/ 6580]
# loss: 0.012512  [ 2700/ 6580]
# loss: 0.011925  [ 2800/ 6580]
# loss: 0.014797  [ 2900/ 6580]
# loss: 0.013171  [ 3000/ 6580]
# loss: 0.014530  [ 3100/ 6580]
# loss: 0.011795  [ 3200/ 6580]
# loss: 0.014022  [ 3300/ 6580]
# loss: 0.012494  [ 3400/ 6580]
# loss: 0.014242  [ 3500/ 6580]
# loss: 0.012258  [ 3600/ 6580]
# loss: 0.014775  [ 3700/ 6580]
# loss: 0.013966  [ 3800/ 6580]
# loss: 0.014931  [ 3900/ 6580]
# loss: 0.012773  [ 4000/ 6580]
# loss: 0.015106  [ 4100/ 6580]
# loss: 0.014252  [ 4200/ 6580]
# loss: 0.012792  [ 4300/ 6580]
# loss: 0.011537  [ 4400/ 6580]
# loss: 0.012127  [ 4500/ 6580]
# loss: 0.014991  [ 4600/ 6580]
# loss: 0.011095  [ 4700/ 6580]
# loss: 0.011779  [ 4800/ 6580]
# loss: 0.010315  [ 4900/ 6580]
# loss: 0.012444  [ 5000/ 6580]
# loss: 0.013215  [ 5100/ 6580]
# loss: 0.011174  [ 5200/ 6580]
# loss: 0.013792  [ 5300/ 6580]
# loss: 0.012323  [ 5400/ 6580]
# loss: 0.011759  [ 5500/ 6580]
# loss: 0.014657  [ 5600/ 6580]
# loss: 0.011952  [ 5700/ 6580]
# loss: 0.012752  [ 5800/ 6580]
# loss: 0.013170  [ 5900/ 6580]
# loss: 0.011378  [ 6000/ 6580]
# loss: 0.010209  [ 6100/ 6580]
# loss: 0.012860  [ 6200/ 6580]
# loss: 0.014617  [ 6300/ 6580]
# loss: 0.013769  [ 6400/ 6580]
# loss: 0.011200  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 85.8%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 7
# -------------------------------
# loss: 0.011403  [    0/ 6580]
# loss: 0.010296  [  100/ 6580]
# loss: 0.013692  [  200/ 6580]
# loss: 0.011794  [  300/ 6580]
# loss: 0.013550  [  400/ 6580]
# loss: 0.009585  [  500/ 6580]
# loss: 0.011806  [  600/ 6580]
# loss: 0.011802  [  700/ 6580]
# loss: 0.010244  [  800/ 6580]
# loss: 0.013034  [  900/ 6580]
# loss: 0.009657  [ 1000/ 6580]
# loss: 0.012757  [ 1100/ 6580]
# loss: 0.012460  [ 1200/ 6580]
# loss: 0.011807  [ 1300/ 6580]
# loss: 0.009207  [ 1400/ 6580]
# loss: 0.010938  [ 1500/ 6580]
# loss: 0.010188  [ 1600/ 6580]
# loss: 0.011411  [ 1700/ 6580]
# loss: 0.014276  [ 1800/ 6580]
# loss: 0.011651  [ 1900/ 6580]
# loss: 0.011148  [ 2000/ 6580]
# loss: 0.012295  [ 2100/ 6580]
# loss: 0.010804  [ 2200/ 6580]
# loss: 0.010613  [ 2300/ 6580]
# loss: 0.012438  [ 2400/ 6580]
# loss: 0.011606  [ 2500/ 6580]
# loss: 0.009787  [ 2600/ 6580]
# loss: 0.012898  [ 2700/ 6580]
# loss: 0.011133  [ 2800/ 6580]
# loss: 0.010144  [ 2900/ 6580]
# loss: 0.010749  [ 3000/ 6580]
# loss: 0.012725  [ 3100/ 6580]
# loss: 0.009715  [ 3200/ 6580]
# loss: 0.011394  [ 3300/ 6580]
# loss: 0.012657  [ 3400/ 6580]
# loss: 0.009471  [ 3500/ 6580]
# loss: 0.009475  [ 3600/ 6580]
# loss: 0.009686  [ 3700/ 6580]
# loss: 0.009522  [ 3800/ 6580]
# loss: 0.011322  [ 3900/ 6580]
# loss: 0.011159  [ 4000/ 6580]
# loss: 0.010960  [ 4100/ 6580]
# loss: 0.008580  [ 4200/ 6580]
# loss: 0.013794  [ 4300/ 6580]
# loss: 0.011516  [ 4400/ 6580]
# loss: 0.010581  [ 4500/ 6580]
# loss: 0.010553  [ 4600/ 6580]
# loss: 0.010538  [ 4700/ 6580]
# loss: 0.011045  [ 4800/ 6580]
# loss: 0.009013  [ 4900/ 6580]
# loss: 0.010949  [ 5000/ 6580]
# loss: 0.009303  [ 5100/ 6580]
# loss: 0.010870  [ 5200/ 6580]
# loss: 0.008599  [ 5300/ 6580]
# loss: 0.009474  [ 5400/ 6580]
# loss: 0.009652  [ 5500/ 6580]
# loss: 0.010528  [ 5600/ 6580]
# loss: 0.010519  [ 5700/ 6580]
# loss: 0.012622  [ 5800/ 6580]
# loss: 0.009493  [ 5900/ 6580]
# loss: 0.009372  [ 6000/ 6580]
# loss: 0.010008  [ 6100/ 6580]
# loss: 0.011463  [ 6200/ 6580]
# loss: 0.009044  [ 6300/ 6580]
# loss: 0.010441  [ 6400/ 6580]
# loss: 0.010879  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 88.1%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 8
# -------------------------------
# loss: 0.010198  [    0/ 6580]
# loss: 0.010021  [  100/ 6580]
# loss: 0.011735  [  200/ 6580]
# loss: 0.009788  [  300/ 6580]
# loss: 0.008697  [  400/ 6580]
# loss: 0.012665  [  500/ 6580]
# loss: 0.009233  [  600/ 6580]
# loss: 0.010000  [  700/ 6580]
# loss: 0.009491  [  800/ 6580]
# loss: 0.008550  [  900/ 6580]
# loss: 0.009404  [ 1000/ 6580]
# loss: 0.010484  [ 1100/ 6580]
# loss: 0.008793  [ 1200/ 6580]
# loss: 0.008164  [ 1300/ 6580]
# loss: 0.012477  [ 1400/ 6580]
# loss: 0.009301  [ 1500/ 6580]
# loss: 0.009133  [ 1600/ 6580]
# loss: 0.010737  [ 1700/ 6580]
# loss: 0.008577  [ 1800/ 6580]
# loss: 0.011660  [ 1900/ 6580]
# loss: 0.009091  [ 2000/ 6580]
# loss: 0.011412  [ 2100/ 6580]
# loss: 0.008892  [ 2200/ 6580]
# loss: 0.009335  [ 2300/ 6580]
# loss: 0.009673  [ 2400/ 6580]
# loss: 0.011377  [ 2500/ 6580]
# loss: 0.008492  [ 2600/ 6580]
# loss: 0.010229  [ 2700/ 6580]
# loss: 0.009022  [ 2800/ 6580]
# loss: 0.008525  [ 2900/ 6580]
# loss: 0.010866  [ 3000/ 6580]
# loss: 0.006592  [ 3100/ 6580]
# loss: 0.007197  [ 3200/ 6580]
# loss: 0.010281  [ 3300/ 6580]
# loss: 0.008601  [ 3400/ 6580]
# loss: 0.008712  [ 3500/ 6580]
# loss: 0.008359  [ 3600/ 6580]
# loss: 0.009945  [ 3700/ 6580]
# loss: 0.009481  [ 3800/ 6580]
# loss: 0.009658  [ 3900/ 6580]
# loss: 0.009257  [ 4000/ 6580]
# loss: 0.009208  [ 4100/ 6580]
# loss: 0.010438  [ 4200/ 6580]
# loss: 0.010280  [ 4300/ 6580]
# loss: 0.010080  [ 4400/ 6580]
# loss: 0.009747  [ 4500/ 6580]
# loss: 0.008218  [ 4600/ 6580]
# loss: 0.008819  [ 4700/ 6580]
# loss: 0.008662  [ 4800/ 6580]
# loss: 0.007727  [ 4900/ 6580]
# loss: 0.010651  [ 5000/ 6580]
# loss: 0.009224  [ 5100/ 6580]
# loss: 0.007891  [ 5200/ 6580]
# loss: 0.009194  [ 5300/ 6580]
# loss: 0.007664  [ 5400/ 6580]
# loss: 0.008755  [ 5500/ 6580]
# loss: 0.010283  [ 5600/ 6580]
# loss: 0.009860  [ 5700/ 6580]
# loss: 0.008540  [ 5800/ 6580]
# loss: 0.008130  [ 5900/ 6580]
# loss: 0.009935  [ 6000/ 6580]
# loss: 0.009638  [ 6100/ 6580]
# loss: 0.008238  [ 6200/ 6580]
# loss: 0.010531  [ 6300/ 6580]
# loss: 0.009647  [ 6400/ 6580]
# loss: 0.008663  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 89.5%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 9
# -------------------------------
# loss: 0.008333  [    0/ 6580]
# loss: 0.008134  [  100/ 6580]
# loss: 0.008882  [  200/ 6580]
# loss: 0.009029  [  300/ 6580]
# loss: 0.009792  [  400/ 6580]
# loss: 0.008034  [  500/ 6580]
# loss: 0.008538  [  600/ 6580]
# loss: 0.009244  [  700/ 6580]
# loss: 0.008594  [  800/ 6580]
# loss: 0.009362  [  900/ 6580]
# loss: 0.009658  [ 1000/ 6580]
# loss: 0.008678  [ 1100/ 6580]
# loss: 0.008303  [ 1200/ 6580]
# loss: 0.007557  [ 1300/ 6580]
# loss: 0.010109  [ 1400/ 6580]
# loss: 0.007373  [ 1500/ 6580]
# loss: 0.008929  [ 1600/ 6580]
# loss: 0.008801  [ 1700/ 6580]
# loss: 0.008916  [ 1800/ 6580]
# loss: 0.008033  [ 1900/ 6580]
# loss: 0.007431  [ 2000/ 6580]
# loss: 0.008683  [ 2100/ 6580]
# loss: 0.007912  [ 2200/ 6580]
# loss: 0.008908  [ 2300/ 6580]
# loss: 0.010590  [ 2400/ 6580]
# loss: 0.006748  [ 2500/ 6580]
# loss: 0.008084  [ 2600/ 6580]
# loss: 0.009191  [ 2700/ 6580]
# loss: 0.008559  [ 2800/ 6580]
# loss: 0.007796  [ 2900/ 6580]
# loss: 0.007938  [ 3000/ 6580]
# loss: 0.010099  [ 3100/ 6580]
# loss: 0.008277  [ 3200/ 6580]
# loss: 0.007886  [ 3300/ 6580]
# loss: 0.008796  [ 3400/ 6580]
# loss: 0.008079  [ 3500/ 6580]
# loss: 0.009195  [ 3600/ 6580]
# loss: 0.007864  [ 3700/ 6580]
# loss: 0.008822  [ 3800/ 6580]
# loss: 0.009127  [ 3900/ 6580]
# loss: 0.007162  [ 4000/ 6580]
# loss: 0.008283  [ 4100/ 6580]
# loss: 0.008116  [ 4200/ 6580]
# loss: 0.008373  [ 4300/ 6580]
# loss: 0.008729  [ 4400/ 6580]
# loss: 0.008123  [ 4500/ 6580]
# loss: 0.008134  [ 4600/ 6580]
# loss: 0.008050  [ 4700/ 6580]
# loss: 0.007628  [ 4800/ 6580]
# loss: 0.008886  [ 4900/ 6580]
# loss: 0.008691  [ 5000/ 6580]
# loss: 0.006626  [ 5100/ 6580]
# loss: 0.008596  [ 5200/ 6580]
# loss: 0.007383  [ 5300/ 6580]
# loss: 0.008696  [ 5400/ 6580]
# loss: 0.009412  [ 5500/ 6580]
# loss: 0.007670  [ 5600/ 6580]
# loss: 0.007581  [ 5700/ 6580]
# loss: 0.007011  [ 5800/ 6580]
# loss: 0.008001  [ 5900/ 6580]
# loss: 0.008825  [ 6000/ 6580]
# loss: 0.008800  [ 6100/ 6580]
# loss: 0.005820  [ 6200/ 6580]
# loss: 0.006825  [ 6300/ 6580]
# loss: 0.005109  [ 6400/ 6580]
# loss: 0.008251  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 90.5%
# Test Error:
#  Accuracy phase: -0.0
#
# Epoch 10
# -------------------------------
# loss: 0.008282  [    0/ 6580]
# loss: 0.007194  [  100/ 6580]
# loss: 0.006476  [  200/ 6580]
# loss: 0.006163  [  300/ 6580]
# loss: 0.008016  [  400/ 6580]
# loss: 0.007253  [  500/ 6580]
# loss: 0.007878  [  600/ 6580]
# loss: 0.008231  [  700/ 6580]
# loss: 0.007452  [  800/ 6580]
# loss: 0.007758  [  900/ 6580]
# loss: 0.007011  [ 1000/ 6580]
# loss: 0.010521  [ 1100/ 6580]
# loss: 0.006072  [ 1200/ 6580]
# loss: 0.008273  [ 1300/ 6580]
# loss: 0.007738  [ 1400/ 6580]
# loss: 0.007560  [ 1500/ 6580]
# loss: 0.005952  [ 1600/ 6580]
# loss: 0.008157  [ 1700/ 6580]
# loss: 0.005758  [ 1800/ 6580]
# loss: 0.008179  [ 1900/ 6580]
# loss: 0.007226  [ 2000/ 6580]
# loss: 0.007040  [ 2100/ 6580]
# loss: 0.007995  [ 2200/ 6580]
# loss: 0.007222  [ 2300/ 6580]
# loss: 0.007236  [ 2400/ 6580]
# loss: 0.008302  [ 2500/ 6580]
# loss: 0.006151  [ 2600/ 6580]
# loss: 0.007622  [ 2700/ 6580]
# loss: 0.007465  [ 2800/ 6580]
# loss: 0.006968  [ 2900/ 6580]
# loss: 0.007524  [ 3000/ 6580]
# loss: 0.006459  [ 3100/ 6580]
# loss: 0.007564  [ 3200/ 6580]
# loss: 0.006525  [ 3300/ 6580]
# loss: 0.007132  [ 3400/ 6580]
# loss: 0.009452  [ 3500/ 6580]
# loss: 0.008070  [ 3600/ 6580]
# loss: 0.008902  [ 3700/ 6580]
# loss: 0.005150  [ 3800/ 6580]
# loss: 0.006791  [ 3900/ 6580]
# loss: 0.008165  [ 4000/ 6580]
# loss: 0.007433  [ 4100/ 6580]
# loss: 0.008721  [ 4200/ 6580]
# loss: 0.007257  [ 4300/ 6580]
# loss: 0.006580  [ 4400/ 6580]
# loss: 0.006294  [ 4500/ 6580]
# loss: 0.007036  [ 4600/ 6580]
# loss: 0.005667  [ 4700/ 6580]
# loss: 0.008766  [ 4800/ 6580]
# loss: 0.007327  [ 4900/ 6580]
# loss: 0.006438  [ 5000/ 6580]
# loss: 0.007049  [ 5100/ 6580]
# loss: 0.007632  [ 5200/ 6580]
# loss: 0.006289  [ 5300/ 6580]
# loss: 0.007163  [ 5400/ 6580]
# loss: 0.007021  [ 5500/ 6580]
# loss: 0.007002  [ 5600/ 6580]
# loss: 0.005809  [ 5700/ 6580]
# loss: 0.008596  [ 5800/ 6580]
# loss: 0.006030  [ 5900/ 6580]
# loss: 0.007856  [ 6000/ 6580]
# loss: 0.008282  [ 6100/ 6580]
# loss: 0.006666  [ 6200/ 6580]
# loss: 0.006992  [ 6300/ 6580]
# loss: 0.005555  [ 6400/ 6580]
# loss: 0.006857  [ 6500/ 6580]
# Test Error:
#  Accuracy Magnitude |S|: 91.5%
# Test Error:
#  Accuracy phase: -0.0

# %%
torch.save(model, './4700Data_LSTM_MODELS/12-05-23_20EPOCHS.pth')

# %%
#model1 = torch.load('4700Data_LSTM_MODELS/10-05-23_80EPOCHS.pth')

# %% [markdown]
# ## Accuracy Test New Data

# %%
def test1(dataloader, model, loss_fn):
    '''
    Same as test function but without writer to tensorboard
    '''
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correctS, correct_phase = 0, 0, 0
    
    with torch.no_grad():
        for X, y in dataloader:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
            X, y = X.to(device), y.to(device)
            pred = model(X.float())
            test_loss += loss_fn(pred, y).item()
            S, angle = S_overlap(y,pred)  
            correctS += S
            correct_phase += angle
    
    correctS /= num_batches
    correct_phase /= num_batches

    print(f"Test Error: \n Accuracy Magnitude |S|: {(100*correctS):>0.1f}%")
    print(f"Test Error: \n Accuracy phase: {(correct_phase):>0.1f}\n")

# %%
test1(test_loader, model, criterion)
# Out:
# Test Error:
#  Accuracy Magnitude |S|: 98.6%
# Test Error:
#  Accuracy phase: -0.0

# %% [markdown]
# |Model Name: 12-05-23_20EPOCHS.pth|
# |--- |
#
# |Epoch | Accuracy Magnitude |
# | --- | --- |
# |10 | 95.8%|
# |20 |98.4%|

# %% [markdown]
# ## Predictions

# %%
for X,y in test_loader:
    X, y = X.to(device), y.to(device)
    
    Entrada = X
    
    Salida = y
    with torch.inference_mode():
        Prediccion = model(X.float())
    break

# %%
print(Entrada.shape)
print(Prediccion.shape)
print(Salida.shape)
# Out:
# torch.Size([20, 5, 96])
# torch.Size([20, 5, 64])
# torch.Size([20, 5, 64])

# %%
r_n = np.linspace(-1.5,1.5,32)

In_real_vis = Entrada[2,0,0:32].detach().numpy()
In_imag_vis = Entrada[2,0,32:64].detach().numpy()
Pote = Entrada[2,0,64:96].detach().numpy()

Ou_real_vis = Salida[2,0,0:32].detach().numpy()
Ou_imag_vis = Salida[2,0,32:64].detach().numpy()
Pote_next = Entrada[2,1,64:96].detach().numpy()

Pred_real_vis = Prediccion[2,0,0:32].detach().numpy()
Pred_imag_vis = Prediccion[2,0,32:64].detach().numpy()

# %%
fig, axs = plt.subplots(2,2)

# Lenght: au -> Angstroms
axs[0,0].plot(r_n, Pote*(1/1.5936e-3), "-", label="V(r,t)", color=color[3])
axs[0,0].plot(r_n, In_real_vis*20, label="$\psi_{r}(r, t)$", color=color[0])  # Escaled


axs[0,1].plot(r_n, Pote*(1/1.5936e-3), "-", label="V(r,t)", color=color[3])
axs[0,1].plot(r_n, In_imag_vis*20, label="$\psi_{i}(r, t)$", color = color[1])  # Escaled

#axs[0].plot(r_n, Pote_next*(1/1.5936e-3), "-", label="V(r,t)", color=color[3])
axs[1,0].plot(r_n, Ou_real_vis*20, label="$\psi_{r}(r, t+1)_{True}$", color=color[0])  # Escaled
axs[1,0].scatter(r_n, Pred_real_vis*20, label="$\psi_{r}(r, t+1)_{LSTM}$", color=color[4], marker='.')  # Escaled


axs[1,1].plot(r_n, Ou_imag_vis*20, label="$\psi_{i}(r, t+1)_{True}$", color = color[1])  # Escaled
axs[1,1].scatter(r_n, Pred_imag_vis*20, label="$\psi_{i}(r, t+1)_{LSTM}$", color = color[4], marker='.')  # Escaled

for axr1 in axs:
    for axr11 in axr1:
        axr11.set_ylim([-20, 60])
        axr11.legend()
        axr11.set(xlabel='Position [$\AA$]', ylabel='Energy [Kcal/mol]')
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
    
plt.gcf().set_size_inches(9, 5)
plt.legend()    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.9666666666667">

# %%
#------------- t=0
In_real_vis0 = Entrada[2,0,0:32].detach().numpy()
In_imag_vis0 = Entrada[2,0,32:64].detach().numpy()
In_dens0 = (np.abs(np.vectorize(complex)(In_real_vis0,In_imag_vis0)))**2

Pote0 = Entrada[2,0,64:96].detach().numpy()

Ou_real_vis0 = Salida[2,0,0:32].detach().numpy()
Ou_imag_vis0 = Salida[2,0,32:64].detach().numpy()
Ou_dens0 = (np.abs(np.vectorize(complex)(Ou_real_vis0,Ou_imag_vis0)))**2
      
Pred_real_vis0 = Prediccion[2,0,0:32].detach().numpy()
Pred_imag_vis0 = Prediccion[2,0,32:64].detach().numpy()
Pred_dens0 = (np.abs(np.vectorize(complex)(Pred_real_vis0,Pred_imag_vis0)))**2

#-------------- t=1
In_real_vis1 = Entrada[2,1,0:32].detach().numpy()
In_imag_vis1 = Entrada[2,1,32:64].detach().numpy()
Pote1 = Entrada[2,2,64:96].detach().numpy()

Ou_real_vis1 = Salida[2,1,0:32].detach().numpy()
Ou_imag_vis1 = Salida[2,1,32:64].detach().numpy()
Ou_dens1 = (np.abs(np.vectorize(complex)(Ou_real_vis1,Ou_imag_vis1)))**2

Pred_real_vis1 = Prediccion[2,1,0:32].detach().numpy()
Pred_imag_vis1 = Prediccion[2,1,32:64].detach().numpy()
Pred_dens1 = (np.abs(np.vectorize(complex)(Pred_real_vis1,Pred_imag_vis1)))**2

#-------------- t=2
In_real_vis2 = Entrada[2,2,0:32].detach().numpy()
In_imag_vis2 = Entrada[2,2,32:64].detach().numpy()
Pote2 = Entrada[2,2,64:96].detach().numpy()

Ou_real_vis2 = Salida[2,2,0:32].detach().numpy()
Ou_imag_vis2 = Salida[2,2,32:64].detach().numpy()
Ou_dens2 = (np.abs(np.vectorize(complex)(Ou_real_vis2,Ou_imag_vis2)))**2

Pred_real_vis2 = Prediccion[2,2,0:32].detach().numpy()
Pred_imag_vis2 = Prediccion[2,2,32:64].detach().numpy()
Pred_dens2 = (np.abs(np.vectorize(complex)(Pred_real_vis2,Pred_imag_vis2)))**2

#-------------- t=3
In_real_vis3 = Entrada[2,3,0:32].detach().numpy()
In_imag_vis3 = Entrada[2,3,32:64].detach().numpy()
Pote3 = Entrada[2,3,64:96].detach().numpy()

Ou_real_vis3 = Salida[2,3,0:32].detach().numpy()
Ou_imag_vis3 = Salida[2,3,32:64].detach().numpy()
Ou_dens3 = (np.abs(np.vectorize(complex)(Ou_real_vis3,Ou_imag_vis3)))**2

Pred_real_vis3 = Prediccion[2,3,0:32].detach().numpy()
Pred_imag_vis3 = Prediccion[2,3,32:64].detach().numpy()
Pred_dens3 = (np.abs(np.vectorize(complex)(Pred_real_vis3,Pred_imag_vis3)))**2

#-------------- t=4
In_real_vis4 = Entrada[2,4,0:32].detach().numpy()
In_imag_vis4 = Entrada[2,4,32:64].detach().numpy()
Pote4 = Entrada[2,4,64:96].detach().numpy()

Ou_real_vis4 = Salida[2,4,0:32].detach().numpy()
Ou_imag_vis4 = Salida[2,4,32:64].detach().numpy()
Ou_dens4 = (np.abs(np.vectorize(complex)(Ou_real_vis4,Ou_imag_vis4)))**2

Pred_real_vis4 = Prediccion[2,4,0:32].detach().numpy()
Pred_imag_vis4 = Prediccion[2,4,32:64].detach().numpy()
Pred_dens4 = (np.abs(np.vectorize(complex)(Pred_real_vis4,Pred_imag_vis4)))**2

# %%
fig, axs = plt.subplots(3,2)


    
# Time: fs -> au, Lenght: au -> Angstroms, Energy: au -> kcal/mol
axs[0,0].plot(r_n, Pote0*(1/1.5936e-3), "-", label="0 fs", color=color[3])
axs[0,0].plot(r_n, In_dens0*10, label="$|\psi_{initial}(r, t=0)|^{2}$")


axs[0,1].plot(r_n, Pote0*(1/1.5936e-3), "-", label="01 fs", color=color[3])
axs[0,1].scatter(r_n, Pred_dens0*10, label="$|\psi_{LSTM}(r, t=1)|^{2}$", color=color[4], marker='.')
axs[0,1].plot(r_n, Ou_dens0*10, label="$|\psi_{True}(r, t=1)|^{2}$")


axs[1,0].plot(r_n, Pote1*(1/1.5936e-3), "-", label="2 fs", color=color[3])
axs[1,0].scatter(r_n, Pred_dens1*10, label="$|\psi_{LSTM}(r, t=2)|^{2}$", color=color[4], marker='.')
axs[1,0].plot(r_n, Ou_dens1*10, label="$|\psi_{True}(r, t=2)|^{2}$")


axs[1,1].plot(r_n, Pote2*(1/1.5936e-3), "-", label="3 fs", color=color[3])
axs[1,1].scatter(r_n, Pred_dens2*(10), label="$|\psi_{LSTM}(r, t=3)|^{2}$", color=color[4], marker='.')
axs[1,1].plot(r_n, Ou_dens2*10, label="$|\psi_{True}(r, t=3)|^{2}$")

axs[2,0].plot(r_n, Pote3*(1/1.5936e-3), "-", label="4 fs", color=color[3])
axs[2,0].scatter(r_n, Pred_dens3*(10), label="$|\psi_{LSTM}(r, t=4)|^{2}$", color=color[4], marker='.')
axs[2,0].plot(r_n, Ou_dens3*10, label="$|\psi_{True}(r, t=4)|^{2}$")

axs[2,1].plot(r_n, Pote4*(1/1.5936e-3), "-", label="5 fs", color=color[3])
axs[2,1].scatter(r_n, Pred_dens4*(10), label="$|\psi_{LSTM}(r, t=5)|^{2}$", color=color[4], marker='.')
axs[2,1].plot(r_n, Ou_dens4*10, label="$|\psi_{True}(r, t=5)|^{2}$")







for axr1 in axs:
    for axr11 in axr1:
        axr11.set_ylim([-5, 50])
        axr11.legend()
        axr11.set(xlabel='Position [$\AA$]', ylabel='Energy [Kcal/mol]')
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
    
plt.gcf().set_size_inches(6.5, 9)
plt.legend()    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1026">
