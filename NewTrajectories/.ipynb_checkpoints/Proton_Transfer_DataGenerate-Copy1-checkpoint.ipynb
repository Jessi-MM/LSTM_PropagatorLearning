# %% [markdown]
# # Notas
#
# ## Sobre `class ProtonTransfer`
#
#
# El constructor de la clase utiliza los siguientes valores:
# - n: Número de puntos en el grid para el método DVR
# - a: Punto inicial del grid [angstroms]
# - b: Punto final del grid [angstroms]
# - k: Número de eigenestados incluidos para el paquete inicial de onda
# - time: True o False. Determina si se utiliza un potencial dependiente del tiempo: True, o independiente del tiempo: False
#
# *Ejemplo*:
#
# `data = ProtonTransfer(k = 5, n = 32, a=-1.5, b=1.5, time=True)`
#
# ### Para generar un paquete de onda inicial aleatorio
#
# Se utiliza el método Wavepacket_Init:
#
# `data.Wavepacket_Init()`
#
# Devuelve un array de $n$ números complejos
#
# ### Para generar potenciales dependientes del tiempo:V(t) (valores aleatorios)
#
# Se utiliza el método vector_potential:
# `data.vector_potential(t)`
#
# Devuelve un array de $n$ números reales con el potencial [au] al tiempo t en cada punto del grid.
#
# ### Para generar potenciales independientes del tiempo: V (valores aleatorios)
#
# Se utiliza el método vector_potential:
# `data.vector_potential_TI()`
#
# Devuelve un array de $n$ números reales con el potencial [au] en cada punto del grid.
#
# ### Para generar un paquete de onda propagado al tiempo t con V(t)
#
# Se utiliza el método evolution_wp:
# `data.evolution_wp(t = 100, step = 1)`
#
# Devuelve un array de $n$ números complejos correspondientes a la evolución de un paquete inicial al tiempo t [fs], con pasos de 1 [fs].
#
#
# ### Para generar un paquete de onda propagado al tiempo t con V
#
# Se utiliza el método evolution_wp:
# `data.evolution_wp_TI(t = 100, step = 1)`
#
# Devuelve un array de $n$ números complejos correspondientes a la evolución de un paquete inicial al tiempo t [fs], con pasos de 1 [fs]. Para un potencial independiente del tiempo.
#
#
# ## Sobre `class Potential_System`
#
# Se utiliza para generar las funciones del modelo físico del potencial: [artículo principal](https://doi.org/10.1021/acs.jpclett.1c03117)

# %%
import random
import numpy as np
from numpy import ogrid
from numpy.linalg import eig
#import matplotlib.pyplot as plt
import cmath
from scipy import integrate
# Enable interactive plot
#%matplotlib notebook
from tabulate import tabulate
#import matplotlib.animation as anim
import os

#plt.style.use('seaborn')

# %%
class Potential_System:
    
    def __init__(self, time = True, var_random = True):
        
        
        if time == True:  # Time Dependent Potential
            if var_random == True:
                self.V = 10*1.5936e-3  # Electronic coupling [kcal/mol] -> au
                self.w1 = random.uniform(1500,4000)*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.w2 = random.uniform(1500,4000)*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.l = random.uniform(0,10)*1.5936e-3  # Amplitude of the energy bias [kcal/mol] -> au
                self.x_eq = random.uniform(-10,10)*1.5936e-3  # Equilibrium energy bias [kcal/mol] -> au
                self.w_x = 0.0148*(1/41.34144)  # Frequency of the energy bias oscillations [fs^-1] -> au
                self.th_x = random.uniform(0, 2*np.pi)  # Initial phase. Zero for the time-independent potentials
                self.R_eq = random.uniform(0.2, 1.0)*(1/0.5291775)  # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.R_0 = random.uniform(0, self.R_eq)  # Initial displacement from equilibrium
                self.w_R = random.uniform(100, 300)*4.556e-6  # Frecuency of the proton-donor-acceptor distance oscillation [cm^-1] -> au
                self.th_R = random.uniform(0, 2*np.pi)  # Random initial phase 
                self.m = 1836  #The proton mass [au]
            
            if var_random == False:
                self.V = 10*1.5936e-3  # Electronic coupling [kcal/mol] -> au
                self.w1 = float(input('Enter w1 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6
                self.w2 = float(input('Enter w2 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6
                self.l = float(input('Enter l (Amplitude of the energy bias [kcal/mol]): \n'))*1.5936e-3  # Amplitude of the energy bias [kcal/mol] -> au
                self.x_eq = float(input('Enter x_eq (Equilibrium energy bias [kcal/mol]): \n'))*1.5936e-3  # Equilibrium energy bias [kcal/mol] -> au
                self.w_x = 0.0148*(1/41.34144)  # Frequency of the energy bias oscillations [fs^-1] -> au
                self.th_x = float(input('Enter th_x (Initial phase from 0 to 2pi [rad]): \n'))  # Initial phase. Zero for the time-independent potentials
                self.R_eq = float(input('Enter R_eq (Equilibrium distance between the minima of the harmonic potential [0.1nm]): \n'))*(1/0.5291775)  # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.R_0 = float(input('Enter R_0 (Initial displacement from equilibrium from 0 to R_eq [0.1nm]): \n'))*(1/0.5291775)  # Initial displacement from equilibrium
                self.w_R = float(input('Enter w_r (Frecuency of the proton-donor-acceptor distance oscillation [cm^-1]): \n'))*4.556e-6  # Frecuency of the proton-donor-acceptor distance oscillation [cm^-1] -> au
                self.th_R = float(input('Enter th_R (Random initial phase from 0 to 2pi [rad])'))  # Random initial phase 
                self.m = 1836  #The proton mass [au]
                
                
                
        if time == False:  # Time Independent Potential
            if var_random == False:
                self.V = 10*1.5936e-3  # Electronic coupling [kcal/mol] -> au
                self.w1 = float(input('Enter w1 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.w2 = float(input('Enter w2 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.x_eq = float(input('Enter x_eq (Equilibrium energy bias [kcal/mol]): \n'))*1.5936e-3 # Equilibrium energy bias [kcal/mol] -> au
                self.R_eq = float(input('Enter R_eq (Equilibrium distance between the minima of the harmonic potential [0.1nm]): \n'))*(1/0.5291775) # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.m = 1836  #The proton mass [au]
                
            if var_random == True:
                self.V =  10*1.5936e-3 # Electronic coupling [kcal/mol] -> au
                self.w1 = random.uniform(1500,4000)*4.556e-6# Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.w2 = random.uniform(1500,4000)*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.x_eq = random.uniform(-10,10)*1.5936e-3  # Equilibrium energy bias [kcal/mol] -> au
                self.R_eq = random.uniform(0.2, 1.0)*(1/0.5291775)  # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.m = 1836  #The proton mass [au]
                
    '''            
    def get_values(self):
        if self.time == True:
            print("====== Time Dependent Potential ======")
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["l [kcal/mol]", self.l*(1/1.5936e-3)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["w_x [fs^-1]", self.w_x*(41.34144)], ["th_x [rad]", self.th_x], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["R_0 [0.1 nm]", self.R_0*(0.5291775)], ["w_R [cm^-1]", self.w_R*(1/4.556e-6)], ["th_R [rad]", self.th_R], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        if self.time == False:
            print("====== Time Independent Potential ======")
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
    '''
    #=== System Functions ================================== 
    
    #--- Time Dependent Potential --------------------------
    def X(self, t):
        """
        Variables:
        l : Amplitude of the energy bias [a_0]
        w_x: Frequency of the energy bias oscillations [Jiffy^-1]
        th_x: Initial phase
        x_eq: Equilibrium energy bias [au]
    
        Input:
        t: Time [Jiffy]
    
        Output:
        X_t: Collective energy gap coordinate [au]
        """
        X_t = self.l*np.cos(self.w_x*t+self.th_x) + self.x_eq
        return X_t
    
    
    def R(self, t):
        """
        Variables:
        R_0: Initial displacement from equilibrium [a_0]
        R_eq: Equilibrium distance between the minima of the harmonic potential [a_0]
        w_R: Frecuency of the proton-donor-acceptor distance oscillation [cm^-1]
        th_R: Random initial phase
    
        Input:
        t : Time [Jiffy]
    
        Output:
        R_t: Vibrations of the proton donor and acceptor [a_0]
        """
        R_t = (self.R_0-self.R_eq)*np.cos(self.w_R*t+self.th_R) + self.R_eq
        return R_t
    
    def u1(self, r, t):
        """
        Variables:
        m : Proton mass [m_e]
        w1: Frecuencies of the harmonic proton potentials [cm^-1]
        R(t): Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jify]
    
        Output:
        u1_t: Harmonic oscillator potential [au]
    
        """
        u1_t = (1/2)*self.m*(self.w1**2)*(r + (self.R(t)/2))**2
        return u1_t


    def u2(self, r, t):
        """
        Variables:
        m : Proton mass [m_e]
        w2: Frecuencies of the harmonic proton potentials [cm^-1]
        R(t): Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jiffy]
    
        Output:
        u2_t: Harmonic oscillator potential [au]
    
        """
        u2_t = (1/2)*self.m*(self.w2**2)*(r - (self.R(t)/2))**2
        return u2_t
    
    #=== Potential of system ==============================
    #--- Time Dependent Potential
    
    def matrix_potential(self, r, t):
        """
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jiffy]
    
        Output:
        Potential Matrix
    
        """
        matrix = np.array([[self.u1(r,t),self.V],[self.V,self.u2(r,t) + self.X(t)]])
        return matrix
    
    def potential(self, r, t):
        """
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jiffy]
    
        Output:
        The lowest eigenvalue of potential matrix  
        """
        e_val = np.linalg.eigvals(self.matrix_potential(r,t))
    
        if e_val[0] < e_val[1]:
            pot = e_val[0]
        else:
            pot = e_val[1]
        return pot
    
    #--- Time Independent Potential ----------------------------
    def u1_TI(self, r):
        """
        Variables:
        m : Proton mass [m_e]
        w1: Frecuencies of the harmonic proton potentials [cm^-1]
        R_eq: Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        u1_t: Harmonic oscillator potential [au]
    
        """
        u1_t = (1/2)*self.m*(self.w1**2)*(r + (self.R_eq/2))**2
        return u1_t


    def u2_TI(self, r):
        """
        Variables:
        m : Proton mass [m_e]
        w2: Frecuencies of the harmonic proton potentials [cm^-1]
        R_eq: Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        u2_t: Harmonic oscillator potential [au]
    
        """
        u2_t = (1/2)*self.m*(self.w2**2)*(r - (self.R_eq/2))**2
        return u2_t
    
    #=== Potential of system ==============================
    #--- Time Independent Potential
    
    def matrix_potential_TI(self, r):
        """
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        Potential Matrix
    
        """
        matrix = np.array([[self.u1_TI(r),self.V],[self.V,self.u2_TI(r) + self.x_eq]])
        return matrix
    
    def potential_TI(self, r):
        """
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        The lowest eigenvalue of potential matrix  
        """
        e_val = np.linalg.eigvals(self.matrix_potential_TI(r))
    
        if e_val[0] < e_val[1]:
            pot = e_val[0]
        else:
            pot = e_val[1]
        return pot

# %%
class ProtonTransfer(Potential_System):
    
    def __init__(self, n, a, b, k, time, var_random, save_dir):
        """
        Input:
        n: Number of points on the grid to DVR method
        a: Initial point of grid [angstroms]
        b: Final point of grid [angstroms]
        k: Number of eigenestatos included in the initial wavepacket
        
        Output:
        a,b & grid r_n in atomic units: au 
        """
        
        self.n = n  # Number of points on the grid to DVR method
        self.a = a*(1/0.5291775)  # Initial point of grid [au]
        self.b = b*(1/0.5291775)  # Final point of grid [au]
        self.k = k  # Number of eigenestatos included in the initial wavepacket
        self.time = time  # True: Time Dependent Potential / False: Time Independent Potential
        self.var_random = var_random  # True: Initialization with random values 
        self.save_dir = save_dir
        
        os.makedirs('./'+self.save_dir+'/Wavepacket')
        os.makedirs('./'+self.save_dir+'/Potential')
        
        self.r_n = ogrid[self.a:self.b:(0+1j)*self.n]  # Grid position [au]
        super().__init__(time = self.time, var_random = self.var_random)
        
    
    def get_values_Potential(self):
        if self.time == True:
            with open('./'+self.save_dir+'/Values_PotentialSystem.txt', 'w') as f:
                f.write('====== Time Dependent Potential ======\n')
                f.write(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["l [kcal/mol]", self.l*(1/1.5936e-3)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["w_x [fs^-1]", self.w_x*(41.34144)], ["th_x [rad]", self.th_x], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["R_0 [0.1 nm]", self.R_0*(0.5291775)], ["w_R [cm^-1]", self.w_R*(1/4.556e-6)], ["th_R [rad]", self.th_R], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
            print('====== Time Dependent Potential ======\n')
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["l [kcal/mol]", self.l*(1/1.5936e-3)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["w_x [fs^-1]", self.w_x*(41.34144)], ["th_x [rad]", self.th_x], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["R_0 [0.1 nm]", self.R_0*(0.5291775)], ["w_R [cm^-1]", self.w_R*(1/4.556e-6)], ["th_R [rad]", self.th_R], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
        if self.time == False:
            with open('./'+self.save_dir+'/Values_PotentialSystem.txt', 'w') as f:
                f.write('====== Time Independent Potential ======')
                f.write((tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl')))
            print("====== Time Independent Potential ======")
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
        
    def get_values_Trajectory(self, t, step):
        with open('./'+self.save_dir+'/Values_Trajectory.txt', 'w') as f:
                f.write(tabulate([["Divisiones en el grid (n):", self.n],["Number of eigenstates to generate the initial wavepacket (k):", self.k],["Time of trajectory (t):", t], ["Step of trajectory:", step]],headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
    
    
    
    

    #=== Random wavepacket initial =============================================
        
    def __eigenestados__(self, r, m):
        a1 = self.a*0.5291775  # au -> angstroms
        b1 = self.b*0.5291775  # au -> angstroms
        e_m =((2/(self.b-self.a))**(1/2))*np.sin((m*np.pi*(r-self.a))/(self.b-self.a))
        return e_m
        
    
    def __phi_i__(self, m):
        phi = np.zeros(self.n)
        j = 0
        for j, i in enumerate(self.r_n):
            phi[j] = self.__eigenestados__(i, m)
        return phi
    
    def __random_Ci__(self):
        cix = random.random()
        ciy = random.random()
        Ci = complex(cix,ciy)
        return Ci
    
    def Wavepacket_Init(self):
        #random.seed(0)
        Ci_norm = []
        wavei = np.zeros([self.k,self.n], dtype = 'complex_')
        for i in range(1,self.k+1):
            Ci = self.__random_Ci__()
            Ci_norm.append(np.abs(Ci)**2)
            wavei[i-1,:] = Ci*(self.__phi_i__(i))
        wave = sum(wavei[i] for i in range(self.k))         
        
        return wave/np.sqrt(sum(Ci_norm))
    
    
    def gaussi(self):
        mu = np.random.uniform(-0.5,0.5)*(1/0.5291775)
        sigma = np.random.uniform(0.1,0.3)*(1/0.5291775)
        Ci = self.__random_Ci__()
        g = Ci*(1/sigma*np.sqrt(2*np.pi))*np.exp(-((self.r_n-mu)**2)/(2*sigma**2))
    
        norm = integrate.simpson((np.abs(g)**2), self.r_n)
        return g/np.sqrt(norm)
    
    
    
    #=== Vector Potential =======================================
    
    def vector_potential(self, t, step=1):
        """
        Input:
        t: Time [fs]
    
        Output:
        Potential in the grid at time t (lenght: 32)
        """
        for j in range(0,t+1, step):
            v_pot = np.zeros(self.n)
            for i, item in enumerate(self.r_n):
                v_pot[i] = self.potential(item,j*41.34)  # fs -> au
            with open(os.path.join('./'+self.save_dir+'/Potential', str(j)+'-potential.npy'), 'wb') as f:
                np.save(f, v_pot)
            
        
        return v_pot
        
    
    def vector_potential_TI(self):
        """
    
        Output:
        Potential in the grid (lenght: 32)
        """
        v_pot = np.zeros(self.n)
        for i, item in enumerate(self.r_n):
            v_pot[i] = self.potential_TI(item)
            
        with open(os.path.join('./'+self.save_dir+'/Potential', str(t)+'-potential.npy'), 'wb') as f:
                np.save(f, v_pot)
        
        return v_pot
    
    
    #=== Kinetic Energy Matrix =================================
    def __senno__(self, k,l,n):
        y = (n**2)*(np.sin((n*np.pi*k)/self.n))*(np.sin((n*np.pi*l)/self.n))
        return y


    def KINETIC_DVR(self):
        h_bar = 1  # Constante de Planck en au
        T_c = ((h_bar**2)/(2*self.m))*((np.pi/(self.b-self.a))**2)*(2/self.n)
        T1 = np.arange(1,self.n-1)
    
        T_DVR = np.zeros((self.n,self.n))  # Matriz de enerfía cinética (fija) [au]

        for i in range(1,self.n-1):
            for j in range(1,self.n-1):
                c = []
                for n in T1:
                    c.append(self.__senno__(i,j,n))
                T_DVR[i,j] = T_c*sum(c)
        
        return T_DVR
    
    #=== Potential Matrix ==============================
    def V_DVR(self, t):
        """
        Input: t [au]
    
        Output: Matriz de potencial en el grid: V_DVR [au]
        """
        V = np.zeros((self.n,self.n))
    
        for i, r in enumerate(self.r_n):
            V[i,i] = self.potential(r,(t))#*(1/1.5936e-3)  # time: fs -> au, energy: Hartree -> kcal/mol
        
        return V
    
    #=== Hamiltonian Matrix ==============================
    def H_DVR(self,t):
        """
        input: tiempo [fs]
    
        output: Matriz Hamiltoniana DVR [au]
        """
        T_DVR = self.KINETIC_DVR()
        t = t*41.34  # fs -> au
        H = T_DVR + self.V_DVR(t)
        return H
    
    
    #=== Time Independent Potential Matrix ==============================
    def V_DVR_TI(self):
        """
        Output: Matriz de potencial en el grid: V_DVR [au]
        """
        V = np.zeros((self.n,self.n))
    
        for i, r in enumerate(self.r_n):
            V[i,i] = self.potential_TI(r)#*(1/1.5936e-3)  # time: fs -> au, energy: Hartree -> kcal/mol
        
        return V
    
    #=== Time Independent Hamiltonian Matrix ==============================
    def H_DVR_TI(self):
        """
    
        output: Matriz Hamiltoniana DVR [au]
        """
        T_DVR = self.KINETIC_DVR()
        H = T_DVR + self.V_DVR_TI()
        return H
    
    
    
    
    
    
    #=== Propagation wavepacket Time Dependent Potential ==========================
    # Find eigenvalues and eigenvectors:
    def eigenN(self,t):
        Eigen_n, U = eig(self.H_DVR(t))
    
        U_inv = np.linalg.inv(U)
    
        D = np.dot(np.dot(U_inv, self.H_DVR(t)),U)
        D = (complex(0,-1))*t*D
        
        return Eigen_n, U, U_inv, D
    
    
    def Psi_VDR_t(self, t, Psi_DVR_inicial):
    
        Eigen_n, U, U_inv, D = self.eigenN(t)
    
        Diag = np.zeros([self.n,self.n], dtype = 'complex_')
        for i in range(self.n):
            Diag[i][i] = np.exp(np.diagonal(D))[i]
    
    
        Psi_DVR_final = np.dot((np.dot(np.dot(U, Diag),U_inv)),Psi_DVR_inicial)
        
        # Normalization
        norm = integrate.simpson((np.abs(Psi_DVR_final)**2), self.r_n)
        
    
        return Psi_DVR_final/np.sqrt(norm)
    
    
    def evolution_wp(self, t, step, gaussiana):
        """
        Función que calcula la evolución del wavepacket inicial a un tiempo t bajo el potencial dado.
        Los intervalos de tiempo son de 1 fs
    
        Input:
        t: tiempo de evolución [fs]
    
        Output:
        wp: Wavepacket evolucionado con el método DVR bajo el potencial V(t)
        """
        
        #-if t == 0:
            #-wp = self.Wavepacket_Init()
            #-with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                #-np.save(f, wp)
            #-return wp
        if t == 0:
            if gaussiana==True:
                wp = self.gaussi()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp
            if gaussiana==False:
                wp = self.Wavepacket_Init()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp
                
        
        else:
            wp = self.Psi_VDR_t(t, self.evolution_wp(t-step, step, gaussiana))
            with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                np.save(f, wp)
                
        
            return wp

    
    
    #=== Time Independent Propagation wavepacket ==========================
    # Find eigenvalues and eigenvectors:
    def eigenN_TI(self):
        Eigen_n, U = eig(self.H_DVR_TI())
    
        U_inv = np.linalg.inv(U)
    
        D = np.dot(np.dot(U_inv, self.H_DVR_TI()),U)
        D = (complex(0,-1))*t*D
        
        return Eigen_n, U, U_inv, D
    
    
    def Psi_VDR_t_TI(self, Psi_DVR_inicial):
    
        Eigen_n, U, U_inv, D = self.eigenN_TI()
    
        Diag = np.zeros([self.n,self.n], dtype = 'complex_')
        for i in range(self.n):
            Diag[i][i] = np.exp(np.diagonal(D))[i]
    
    
        Psi_DVR_final = np.dot((np.dot(np.dot(U, Diag),U_inv)),Psi_DVR_inicial)
    
        # Normalizacion:
        norm = integrate.simpson((np.abs(Psi_DVR_final)**2), self.r_n)

        
    
        return Psi_DVR_final/np.sqrt(norm)
    
    
    def evolution_wp_TI(self, t, step, gaussiana):
        """
        Función que calcula la evolución del wavepacket inicial a un tiempo t bajo el potencial dado.
        Los intervalos de tiempo son de 1 fs
        * Colocar múltiplos enteros de step
    
        Input:
        t: tiempo de evolución [fs]
    
        Output:
        wp: Wavepacket evolucionado con el método DVR bajo el potencial V(t)
        """
        if t == 0:
            if gaussiana == False:
                wp = self.Wavepacket_Init()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp 
            if gaussiana == True:
                wp = self.gaussi()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp 
        else:
            wp = self.Psi_VDR_t_TI(self.evolution_wp_TI(t-step, step, gaussiana))
            with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                np.save(f, wp)
            return wp
    
    
    def density(self, wavepacket):
        dens = (np.abs(wavepacket))**2
        return dens

# %% [markdown]
# # Type II: Time Dependent Potential
#
#
# # Datos con gaussianas, n=32, Trajectoryes = 200 fs, tstep = 1 fs

# %%
for i in range(3700,4000,1):
    d = ProtonTransfer(n=32, a=-1.5, b=1.5, k=1, time=True, var_random=True, save_dir='data'+str(i))
    d.vector_potential(200, step=1)
    d.get_values_Potential()
    d.get_values_Trajectory(200, step=1)
    d.evolution_wp(200, step=1, gaussiana=True)
# Out:
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2848.94      |
# | w2 [cm^-1]           | 3569.1       |
# | l [kcal/mol]         |    6.11604   |
# | x_eq [kcal/mol]      |    0.995042  |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.52592   |
# | R_eq [0.1 nm]        |    0.958315  |
# | R_0 [0.1 nm]         |    0.0837335 |
# | w_R [cm^-1]          |  195.169     |
# | th_R [rad]           |    1.16406   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3571.94      |
# | w2 [cm^-1]           | 3146.61      |
# | l [kcal/mol]         |    0.693271  |
# | x_eq [kcal/mol]      |   -6.64953   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.32487   |
# | R_eq [0.1 nm]        |    0.956864  |
# | R_0 [0.1 nm]         |    0.0416642 |
# | w_R [cm^-1]          |  286.327     |
# | th_R [rad]           |    2.72793   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2044.45     |
# | w2 [cm^-1]           | 3485.52     |
# | l [kcal/mol]         |    9.92529  |
# | x_eq [kcal/mol]      |   -3.91129  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.61223  |
# | R_eq [0.1 nm]        |    0.734808 |
# | R_0 [0.1 nm]         |    0.357475 |
# | w_R [cm^-1]          |  206.684    |
# | th_R [rad]           |    6.09814  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2230.87     |
# | w2 [cm^-1]           | 2939.8      |
# | l [kcal/mol]         |    6.89886  |
# | x_eq [kcal/mol]      |   -8.66813  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.21185  |
# | R_eq [0.1 nm]        |    0.365562 |
# | R_0 [0.1 nm]         |    0.323361 |
# | w_R [cm^-1]          |  127.444    |
# | th_R [rad]           |    1.72097  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1754.17      |
# | w2 [cm^-1]           | 1851.82      |
# | l [kcal/mol]         |    6.13192   |
# | x_eq [kcal/mol]      |    5.49397   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    0.11112   |
# | R_eq [0.1 nm]        |    0.282318  |
# | R_0 [0.1 nm]         |    0.0840172 |
# | w_R [cm^-1]          |  194.946     |
# | th_R [rad]           |    2.21053   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3933.15      |
# | w2 [cm^-1]           | 3878.77      |
# | l [kcal/mol]         |    0.449449  |
# | x_eq [kcal/mol]      |   -1.84753   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    1.42816   |
# | R_eq [0.1 nm]        |    0.200348  |
# | R_0 [0.1 nm]         |    0.0369051 |
# | w_R [cm^-1]          |  264.736     |
# | th_R [rad]           |    0.549296  |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3150.23     |
# | w2 [cm^-1]           | 3143.47     |
# | l [kcal/mol]         |    9.56298  |
# | x_eq [kcal/mol]      |   -6.71995  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.11379  |
# | R_eq [0.1 nm]        |    0.748604 |
# | R_0 [0.1 nm]         |    0.259258 |
# | w_R [cm^-1]          |  290.438    |
# | th_R [rad]           |    3.47866  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2835.18     |
# | w2 [cm^-1]           | 1604.13     |
# | l [kcal/mol]         |    5.32393  |
# | x_eq [kcal/mol]      |   -0.970342 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.01381  |
# | R_eq [0.1 nm]        |    0.712273 |
# | R_0 [0.1 nm]         |    0.570623 |
# | w_R [cm^-1]          |  178.063    |
# | th_R [rad]           |    2.01817  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3189.17     |
# | w2 [cm^-1]           | 3377.72     |
# | l [kcal/mol]         |    9.34255  |
# | x_eq [kcal/mol]      |    4.47708  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.75136  |
# | R_eq [0.1 nm]        |    0.600624 |
# | R_0 [0.1 nm]         |    0.532932 |
# | w_R [cm^-1]          |  209.302    |
# | th_R [rad]           |    0.977731 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3450.26     |
# | w2 [cm^-1]           | 2148.28     |
# | l [kcal/mol]         |    1.99874  |
# | x_eq [kcal/mol]      |   -6.2422   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.36358  |
# | R_eq [0.1 nm]        |    0.314005 |
# | R_0 [0.1 nm]         |    0.201276 |
# | w_R [cm^-1]          |  126.585    |
# | th_R [rad]           |    3.07677  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3245.02     |
# | w2 [cm^-1]           | 3367.22     |
# | l [kcal/mol]         |    6.97268  |
# | x_eq [kcal/mol]      |   -0.799205 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.49873  |
# | R_eq [0.1 nm]        |    0.494814 |
# | R_0 [0.1 nm]         |    0.271478 |
# | w_R [cm^-1]          |  165.621    |
# | th_R [rad]           |    5.03383  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3363.03      |
# | w2 [cm^-1]           | 3362.94      |
# | l [kcal/mol]         |    0.283532  |
# | x_eq [kcal/mol]      |   -6.17111   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.03908   |
# | R_eq [0.1 nm]        |    0.244515  |
# | R_0 [0.1 nm]         |    0.0140735 |
# | w_R [cm^-1]          |  273.844     |
# | th_R [rad]           |    5.10486   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3513.36     |
# | w2 [cm^-1]           | 1682.09     |
# | l [kcal/mol]         |    2.38064  |
# | x_eq [kcal/mol]      |    9.35347  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.05451  |
# | R_eq [0.1 nm]        |    0.405973 |
# | R_0 [0.1 nm]         |    0.197521 |
# | w_R [cm^-1]          |  202.773    |
# | th_R [rad]           |    5.43645  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2142.61     |
# | w2 [cm^-1]           | 2789.3      |
# | l [kcal/mol]         |    6.31289  |
# | x_eq [kcal/mol]      |   -1.09828  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.94403  |
# | R_eq [0.1 nm]        |    0.617167 |
# | R_0 [0.1 nm]         |    0.251794 |
# | w_R [cm^-1]          |  297.821    |
# | th_R [rad]           |    3.54454  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1601.12     |
# | w2 [cm^-1]           | 2390.64     |
# | l [kcal/mol]         |    7.59912  |
# | x_eq [kcal/mol]      |    2.06021  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.05244  |
# | R_eq [0.1 nm]        |    0.310016 |
# | R_0 [0.1 nm]         |    0.211922 |
# | w_R [cm^-1]          |  221.442    |
# | th_R [rad]           |    4.68907  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1519.88     |
# | w2 [cm^-1]           | 3531.52     |
# | l [kcal/mol]         |    0.930386 |
# | x_eq [kcal/mol]      |   -3.53878  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.921746 |
# | R_eq [0.1 nm]        |    0.663544 |
# | R_0 [0.1 nm]         |    0.422531 |
# | w_R [cm^-1]          |  156.364    |
# | th_R [rad]           |    4.29443  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3233.73     |
# | w2 [cm^-1]           | 2327.96     |
# | l [kcal/mol]         |    2.90989  |
# | x_eq [kcal/mol]      |    2.17832  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.82633  |
# | R_eq [0.1 nm]        |    0.850483 |
# | R_0 [0.1 nm]         |    0.315991 |
# | w_R [cm^-1]          |  173.225    |
# | th_R [rad]           |    4.23737  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |         Value |
# |----------------------+---------------|
# | V [kcal/mol]         |   10          |
# | w1 [cm^-1]           | 1821.94       |
# | w2 [cm^-1]           | 2944.87       |
# | l [kcal/mol]         |    6.83548    |
# | x_eq [kcal/mol]      |   -1.29356    |
# | w_x [fs^-1]          |    0.0148     |
# | th_x [rad]           |    0.00775302 |
# | R_eq [0.1 nm]        |    0.384989   |
# | R_0 [0.1 nm]         |    0.378258   |
# | w_R [cm^-1]          |  164.059      |
# | th_R [rad]           |    5.95672    |
# | m (Proton mass [au]) | 1836          |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2180.06     |
# | w2 [cm^-1]           | 1588.48     |
# | l [kcal/mol]         |    8.78823  |
# | x_eq [kcal/mol]      |   -5.17507  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.95469  |
# | R_eq [0.1 nm]        |    0.639574 |
# | R_0 [0.1 nm]         |    0.575525 |
# | w_R [cm^-1]          |  100.93     |
# | th_R [rad]           |    2.98531  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3051.84     |
# | w2 [cm^-1]           | 2960.72     |
# | l [kcal/mol]         |    4.15491  |
# | x_eq [kcal/mol]      |   -8.00532  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.67327  |
# | R_eq [0.1 nm]        |    0.210545 |
# | R_0 [0.1 nm]         |    0.180903 |
# | w_R [cm^-1]          |  235.901    |
# | th_R [rad]           |    4.02014  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2490.1       |
# | w2 [cm^-1]           | 2801.26      |
# | l [kcal/mol]         |    2.32007   |
# | x_eq [kcal/mol]      |    9.34198   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    0.309997  |
# | R_eq [0.1 nm]        |    0.755445  |
# | R_0 [0.1 nm]         |    0.0370126 |
# | w_R [cm^-1]          |  258.63      |
# | th_R [rad]           |    5.41184   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3846.08     |
# | w2 [cm^-1]           | 1920.66     |
# | l [kcal/mol]         |    7.87658  |
# | x_eq [kcal/mol]      |   -7.66537  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.76965  |
# | R_eq [0.1 nm]        |    0.477645 |
# | R_0 [0.1 nm]         |    0.448213 |
# | w_R [cm^-1]          |  225.82     |
# | th_R [rad]           |    3.30981  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3703.3       |
# | w2 [cm^-1]           | 2488.33      |
# | l [kcal/mol]         |    8.24777   |
# | x_eq [kcal/mol]      |   -4.35542   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    4.38084   |
# | R_eq [0.1 nm]        |    0.902702  |
# | R_0 [0.1 nm]         |    0.0834658 |
# | w_R [cm^-1]          |  278.52      |
# | th_R [rad]           |    4.06442   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2056.52     |
# | w2 [cm^-1]           | 3307.02     |
# | l [kcal/mol]         |    6.28723  |
# | x_eq [kcal/mol]      |   -2.09156  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.18141  |
# | R_eq [0.1 nm]        |    0.908614 |
# | R_0 [0.1 nm]         |    0.394008 |
# | w_R [cm^-1]          |  268.079    |
# | th_R [rad]           |    2.43974  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3143.26      |
# | w2 [cm^-1]           | 3063.27      |
# | l [kcal/mol]         |    7.68542   |
# | x_eq [kcal/mol]      |    8.24225   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.04971   |
# | R_eq [0.1 nm]        |    0.569564  |
# | R_0 [0.1 nm]         |    0.0694377 |
# | w_R [cm^-1]          |  190.12      |
# | th_R [rad]           |    2.90211   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3378.85     |
# | w2 [cm^-1]           | 3823.57     |
# | l [kcal/mol]         |    5.29549  |
# | x_eq [kcal/mol]      |   -1.0515   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.7669   |
# | R_eq [0.1 nm]        |    0.388649 |
# | R_0 [0.1 nm]         |    0.107974 |
# | w_R [cm^-1]          |  263.939    |
# | th_R [rad]           |    3.52978  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3433.98      |
# | w2 [cm^-1]           | 3050.88      |
# | l [kcal/mol]         |    8.25238   |
# | x_eq [kcal/mol]      |   -5.66943   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    6.23742   |
# | R_eq [0.1 nm]        |    0.678187  |
# | R_0 [0.1 nm]         |    0.0887242 |
# | w_R [cm^-1]          |  105.473     |
# | th_R [rad]           |    3.98978   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2630.53     |
# | w2 [cm^-1]           | 3805.92     |
# | l [kcal/mol]         |    1.97589  |
# | x_eq [kcal/mol]      |   -6.58449  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.48544  |
# | R_eq [0.1 nm]        |    0.541029 |
# | R_0 [0.1 nm]         |    0.517406 |
# | w_R [cm^-1]          |  117.106    |
# | th_R [rad]           |    4.20275  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3983.88     |
# | w2 [cm^-1]           | 2742.49     |
# | l [kcal/mol]         |    7.63761  |
# | x_eq [kcal/mol]      |    1.4153   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.386124 |
# | R_eq [0.1 nm]        |    0.335438 |
# | R_0 [0.1 nm]         |    0.177622 |
# | w_R [cm^-1]          |  201.916    |
# | th_R [rad]           |    3.91162  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3744.01     |
# | w2 [cm^-1]           | 1941.21     |
# | l [kcal/mol]         |    8.30603  |
# | x_eq [kcal/mol]      |   -0.891508 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.70964  |
# | R_eq [0.1 nm]        |    0.825802 |
# | R_0 [0.1 nm]         |    0.766382 |
# | w_R [cm^-1]          |  220.31     |
# | th_R [rad]           |    3.98023  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1581.64     |
# | w2 [cm^-1]           | 2072.67     |
# | l [kcal/mol]         |    3.34862  |
# | x_eq [kcal/mol]      |   -7.54027  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.25489  |
# | R_eq [0.1 nm]        |    0.779749 |
# | R_0 [0.1 nm]         |    0.773458 |
# | w_R [cm^-1]          |  149.656    |
# | th_R [rad]           |    1.55599  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2696.39     |
# | w2 [cm^-1]           | 1864.05     |
# | l [kcal/mol]         |    7.35822  |
# | x_eq [kcal/mol]      |    3.80976  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.50656  |
# | R_eq [0.1 nm]        |    0.518207 |
# | R_0 [0.1 nm]         |    0.436462 |
# | w_R [cm^-1]          |  171.332    |
# | th_R [rad]           |    2.67804  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3941.2      |
# | w2 [cm^-1]           | 2649.86     |
# | l [kcal/mol]         |    7.67061  |
# | x_eq [kcal/mol]      |    3.69234  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.23932  |
# | R_eq [0.1 nm]        |    0.461692 |
# | R_0 [0.1 nm]         |    0.367282 |
# | w_R [cm^-1]          |  136.865    |
# | th_R [rad]           |    6.04016  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2775.36     |
# | w2 [cm^-1]           | 2036.42     |
# | l [kcal/mol]         |    6.99889  |
# | x_eq [kcal/mol]      |    5.50525  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.86969  |
# | R_eq [0.1 nm]        |    0.365333 |
# | R_0 [0.1 nm]         |    0.211911 |
# | w_R [cm^-1]          |  202.686    |
# | th_R [rad]           |    6.24753  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2748.89      |
# | w2 [cm^-1]           | 1817.34      |
# | l [kcal/mol]         |    5.41583   |
# | x_eq [kcal/mol]      |   -8.71029   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.97486   |
# | R_eq [0.1 nm]        |    0.358389  |
# | R_0 [0.1 nm]         |    0.0320853 |
# | w_R [cm^-1]          |  106.585     |
# | th_R [rad]           |    6.14675   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3257.38     |
# | w2 [cm^-1]           | 3374.5      |
# | l [kcal/mol]         |    0.726123 |
# | x_eq [kcal/mol]      |   -2.99368  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.18974  |
# | R_eq [0.1 nm]        |    0.906836 |
# | R_0 [0.1 nm]         |    0.677623 |
# | w_R [cm^-1]          |  205.73     |
# | th_R [rad]           |    1.3122   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1500.69      |
# | w2 [cm^-1]           | 1785.26      |
# | l [kcal/mol]         |    3.55573   |
# | x_eq [kcal/mol]      |   -4.7958    |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.51517   |
# | R_eq [0.1 nm]        |    0.845412  |
# | R_0 [0.1 nm]         |    0.0672439 |
# | w_R [cm^-1]          |  166.933     |
# | th_R [rad]           |    2.46075   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1873.44     |
# | w2 [cm^-1]           | 2107.15     |
# | l [kcal/mol]         |    3.74179  |
# | x_eq [kcal/mol]      |    4.59063  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.29062  |
# | R_eq [0.1 nm]        |    0.739687 |
# | R_0 [0.1 nm]         |    0.62166  |
# | w_R [cm^-1]          |  256.258    |
# | th_R [rad]           |    0.183642 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3351.26      |
# | w2 [cm^-1]           | 3126.64      |
# | l [kcal/mol]         |    4.15171   |
# | x_eq [kcal/mol]      |    2.86407   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.28255   |
# | R_eq [0.1 nm]        |    0.447803  |
# | R_0 [0.1 nm]         |    0.0560351 |
# | w_R [cm^-1]          |  100.315     |
# | th_R [rad]           |    5.62983   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1669.75      |
# | w2 [cm^-1]           | 3943.94      |
# | l [kcal/mol]         |    2.24095   |
# | x_eq [kcal/mol]      |   -9.10882   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.08244   |
# | R_eq [0.1 nm]        |    0.898646  |
# | R_0 [0.1 nm]         |    0.240197  |
# | w_R [cm^-1]          |  283.246     |
# | th_R [rad]           |    0.0988697 |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2826.97      |
# | w2 [cm^-1]           | 2905.84      |
# | l [kcal/mol]         |    7.38687   |
# | x_eq [kcal/mol]      |    3.14628   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.96742   |
# | R_eq [0.1 nm]        |    0.214839  |
# | R_0 [0.1 nm]         |    0.0416341 |
# | w_R [cm^-1]          |  245.386     |
# | th_R [rad]           |    3.34482   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2286.92     |
# | w2 [cm^-1]           | 3616.79     |
# | l [kcal/mol]         |    4.83162  |
# | x_eq [kcal/mol]      |    5.66127  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.27455  |
# | R_eq [0.1 nm]        |    0.993738 |
# | R_0 [0.1 nm]         |    0.806588 |
# | w_R [cm^-1]          |  221.217    |
# | th_R [rad]           |    4.68838  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2737.53     |
# | w2 [cm^-1]           | 3248.1      |
# | l [kcal/mol]         |    2.49639  |
# | x_eq [kcal/mol]      |   -9.22455  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.30177  |
# | R_eq [0.1 nm]        |    0.641471 |
# | R_0 [0.1 nm]         |    0.322994 |
# | w_R [cm^-1]          |  102.972    |
# | th_R [rad]           |    3.25075  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2940.79     |
# | w2 [cm^-1]           | 1689.61     |
# | l [kcal/mol]         |    0.514922 |
# | x_eq [kcal/mol]      |   -6.41306  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.8961   |
# | R_eq [0.1 nm]        |    0.380207 |
# | R_0 [0.1 nm]         |    0.273412 |
# | w_R [cm^-1]          |  148.031    |
# | th_R [rad]           |    6.16936  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3619.62     |
# | w2 [cm^-1]           | 2529.73     |
# | l [kcal/mol]         |    8.71565  |
# | x_eq [kcal/mol]      |    9.56546  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.20209  |
# | R_eq [0.1 nm]        |    0.942382 |
# | R_0 [0.1 nm]         |    0.859435 |
# | w_R [cm^-1]          |  289.421    |
# | th_R [rad]           |    2.11179  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1504.02      |
# | w2 [cm^-1]           | 2341.65      |
# | l [kcal/mol]         |    9.02849   |
# | x_eq [kcal/mol]      |   -8.9591    |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.02296   |
# | R_eq [0.1 nm]        |    0.338081  |
# | R_0 [0.1 nm]         |    0.0427914 |
# | w_R [cm^-1]          |  291.529     |
# | th_R [rad]           |    5.99817   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3050.35     |
# | w2 [cm^-1]           | 2366.06     |
# | l [kcal/mol]         |    2.81538  |
# | x_eq [kcal/mol]      |    5.14726  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.04094  |
# | R_eq [0.1 nm]        |    0.462743 |
# | R_0 [0.1 nm]         |    0.182108 |
# | w_R [cm^-1]          |  214.417    |
# | th_R [rad]           |    2.17007  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3508.99     |
# | w2 [cm^-1]           | 1833.86     |
# | l [kcal/mol]         |    2.13598  |
# | x_eq [kcal/mol]      |    1.9115   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.70551  |
# | R_eq [0.1 nm]        |    0.879838 |
# | R_0 [0.1 nm]         |    0.220718 |
# | w_R [cm^-1]          |  156.679    |
# | th_R [rad]           |    0.6652   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2408.4      |
# | w2 [cm^-1]           | 3954.43     |
# | l [kcal/mol]         |    3.41092  |
# | x_eq [kcal/mol]      |    8.76874  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.52448  |
# | R_eq [0.1 nm]        |    0.621605 |
# | R_0 [0.1 nm]         |    0.482314 |
# | w_R [cm^-1]          |  110.429    |
# | th_R [rad]           |    2.16196  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2790.41     |
# | w2 [cm^-1]           | 3683.93     |
# | l [kcal/mol]         |    4.49767  |
# | x_eq [kcal/mol]      |   -3.91126  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.475047 |
# | R_eq [0.1 nm]        |    0.941812 |
# | R_0 [0.1 nm]         |    0.921507 |
# | w_R [cm^-1]          |  276.301    |
# | th_R [rad]           |    1.93966  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3006.94     |
# | w2 [cm^-1]           | 1993.93     |
# | l [kcal/mol]         |    5.61719  |
# | x_eq [kcal/mol]      |    6.55826  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.20478  |
# | R_eq [0.1 nm]        |    0.744055 |
# | R_0 [0.1 nm]         |    0.316147 |
# | w_R [cm^-1]          |  125.808    |
# | th_R [rad]           |    5.4061   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3911.39      |
# | w2 [cm^-1]           | 2110.4       |
# | l [kcal/mol]         |    8.85213   |
# | x_eq [kcal/mol]      |    8.75505   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    0.0353322 |
# | R_eq [0.1 nm]        |    0.233645  |
# | R_0 [0.1 nm]         |    0.0875674 |
# | w_R [cm^-1]          |  230.016     |
# | th_R [rad]           |    4.62801   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3586.65     |
# | w2 [cm^-1]           | 3258.83     |
# | l [kcal/mol]         |    2.94545  |
# | x_eq [kcal/mol]      |   -7.92215  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.85467  |
# | R_eq [0.1 nm]        |    0.854487 |
# | R_0 [0.1 nm]         |    0.680388 |
# | w_R [cm^-1]          |  265.526    |
# | th_R [rad]           |    0.717109 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2089.57     |
# | w2 [cm^-1]           | 3556.74     |
# | l [kcal/mol]         |    1.62715  |
# | x_eq [kcal/mol]      |   -6.89632  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.46662  |
# | R_eq [0.1 nm]        |    0.874315 |
# | R_0 [0.1 nm]         |    0.199844 |
# | w_R [cm^-1]          |  274.315    |
# | th_R [rad]           |    5.15536  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2762.32      |
# | w2 [cm^-1]           | 1997.44      |
# | l [kcal/mol]         |    6.91243   |
# | x_eq [kcal/mol]      |    7.32204   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    1.2193    |
# | R_eq [0.1 nm]        |    0.417394  |
# | R_0 [0.1 nm]         |    0.0779524 |
# | w_R [cm^-1]          |  118.713     |
# | th_R [rad]           |    4.37535   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3249.52     |
# | w2 [cm^-1]           | 2948.96     |
# | l [kcal/mol]         |    8.52476  |
# | x_eq [kcal/mol]      |   -8.72487  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.09183  |
# | R_eq [0.1 nm]        |    0.645714 |
# | R_0 [0.1 nm]         |    0.187869 |
# | w_R [cm^-1]          |  266.503    |
# | th_R [rad]           |    0.376908 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3174.28      |
# | w2 [cm^-1]           | 2609.17      |
# | l [kcal/mol]         |    9.15223   |
# | x_eq [kcal/mol]      |   -0.418327  |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    0.648007  |
# | R_eq [0.1 nm]        |    0.204025  |
# | R_0 [0.1 nm]         |    0.0988932 |
# | w_R [cm^-1]          |  245.146     |
# | th_R [rad]           |    1.56681   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3952.8      |
# | w2 [cm^-1]           | 2301.06     |
# | l [kcal/mol]         |    8.53715  |
# | x_eq [kcal/mol]      |    5.98671  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.09826  |
# | R_eq [0.1 nm]        |    0.276614 |
# | R_0 [0.1 nm]         |    0.138467 |
# | w_R [cm^-1]          |  252.039    |
# | th_R [rad]           |    1.32319  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1999.44     |
# | w2 [cm^-1]           | 1623.36     |
# | l [kcal/mol]         |    2.6048   |
# | x_eq [kcal/mol]      |   -6.13261  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.97453  |
# | R_eq [0.1 nm]        |    0.571482 |
# | R_0 [0.1 nm]         |    0.134946 |
# | w_R [cm^-1]          |  185.881    |
# | th_R [rad]           |    2.93523  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3565.73     |
# | w2 [cm^-1]           | 3650.5      |
# | l [kcal/mol]         |    6.24135  |
# | x_eq [kcal/mol]      |    3.1064   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.09136  |
# | R_eq [0.1 nm]        |    0.800486 |
# | R_0 [0.1 nm]         |    0.401648 |
# | w_R [cm^-1]          |  113.592    |
# | th_R [rad]           |    5.15349  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3190.25     |
# | w2 [cm^-1]           | 1944.58     |
# | l [kcal/mol]         |    2.11296  |
# | x_eq [kcal/mol]      |   -9.92969  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.92551  |
# | R_eq [0.1 nm]        |    0.472506 |
# | R_0 [0.1 nm]         |    0.362037 |
# | w_R [cm^-1]          |  220.37     |
# | th_R [rad]           |    3.43066  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3554.81      |
# | w2 [cm^-1]           | 2079.14      |
# | l [kcal/mol]         |    2.44217   |
# | x_eq [kcal/mol]      |   -9.90319   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.92935   |
# | R_eq [0.1 nm]        |    0.305296  |
# | R_0 [0.1 nm]         |    0.0973742 |
# | w_R [cm^-1]          |  227.249     |
# | th_R [rad]           |    4.08094   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3302.83     |
# | w2 [cm^-1]           | 3691.44     |
# | l [kcal/mol]         |    8.71985  |
# | x_eq [kcal/mol]      |   -1.43531  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.03394  |
# | R_eq [0.1 nm]        |    0.420802 |
# | R_0 [0.1 nm]         |    0.395225 |
# | w_R [cm^-1]          |  111.857    |
# | th_R [rad]           |    0.648051 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3088.45     |
# | w2 [cm^-1]           | 2680.12     |
# | l [kcal/mol]         |    8.14181  |
# | x_eq [kcal/mol]      |    3.24405  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.925904 |
# | R_eq [0.1 nm]        |    0.809743 |
# | R_0 [0.1 nm]         |    0.183456 |
# | w_R [cm^-1]          |  175.801    |
# | th_R [rad]           |    0.989611 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2911.86     |
# | w2 [cm^-1]           | 1518.61     |
# | l [kcal/mol]         |    5.83541  |
# | x_eq [kcal/mol]      |   -2.41278  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.29027  |
# | R_eq [0.1 nm]        |    0.753412 |
# | R_0 [0.1 nm]         |    0.650602 |
# | w_R [cm^-1]          |  227.184    |
# | th_R [rad]           |    2.66161  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2416.07     |
# | w2 [cm^-1]           | 1643.23     |
# | l [kcal/mol]         |    8.92402  |
# | x_eq [kcal/mol]      |    6.03595  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.910423 |
# | R_eq [0.1 nm]        |    0.67524  |
# | R_0 [0.1 nm]         |    0.18436  |
# | w_R [cm^-1]          |  236.491    |
# | th_R [rad]           |    0.756599 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2669.78      |
# | w2 [cm^-1]           | 3625.98      |
# | l [kcal/mol]         |    4.77782   |
# | x_eq [kcal/mol]      |    1.84506   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.69481   |
# | R_eq [0.1 nm]        |    0.20396   |
# | R_0 [0.1 nm]         |    0.0483314 |
# | w_R [cm^-1]          |  118         |
# | th_R [rad]           |    2.78674   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2721.56     |
# | w2 [cm^-1]           | 1520.34     |
# | l [kcal/mol]         |    2.40449  |
# | x_eq [kcal/mol]      |    7.99545  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.05646  |
# | R_eq [0.1 nm]        |    0.679657 |
# | R_0 [0.1 nm]         |    0.506397 |
# | w_R [cm^-1]          |  144.566    |
# | th_R [rad]           |    0.200339 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |         Value |
# |----------------------+---------------|
# | V [kcal/mol]         |   10          |
# | w1 [cm^-1]           | 3484.33       |
# | w2 [cm^-1]           | 1785.87       |
# | l [kcal/mol]         |    7.48075    |
# | x_eq [kcal/mol]      |   -0.00791366 |
# | w_x [fs^-1]          |    0.0148     |
# | th_x [rad]           |    5.07682    |
# | R_eq [0.1 nm]        |    0.823109   |
# | R_0 [0.1 nm]         |    0.724842   |
# | w_R [cm^-1]          |  153.194      |
# | th_R [rad]           |    2.51041    |
# | m (Proton mass [au]) | 1836          |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2677.63     |
# | w2 [cm^-1]           | 3667.73     |
# | l [kcal/mol]         |    7.95927  |
# | x_eq [kcal/mol]      |    5.21521  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.01135  |
# | R_eq [0.1 nm]        |    0.503204 |
# | R_0 [0.1 nm]         |    0.301556 |
# | w_R [cm^-1]          |  288.508    |
# | th_R [rad]           |    4.74502  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2008.28     |
# | w2 [cm^-1]           | 1595.26     |
# | l [kcal/mol]         |    1.92636  |
# | x_eq [kcal/mol]      |    1.63056  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.598455 |
# | R_eq [0.1 nm]        |    0.840935 |
# | R_0 [0.1 nm]         |    0.552017 |
# | w_R [cm^-1]          |  153.272    |
# | th_R [rad]           |    5.32063  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1958.9      |
# | w2 [cm^-1]           | 1505.99     |
# | l [kcal/mol]         |    7.12534  |
# | x_eq [kcal/mol]      |   -3.18353  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.893807 |
# | R_eq [0.1 nm]        |    0.587762 |
# | R_0 [0.1 nm]         |    0.086034 |
# | w_R [cm^-1]          |  219.524    |
# | th_R [rad]           |    1.28771  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2749.8      |
# | w2 [cm^-1]           | 2696.8      |
# | l [kcal/mol]         |    7.22369  |
# | x_eq [kcal/mol]      |   -5.39209  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.58771  |
# | R_eq [0.1 nm]        |    0.744171 |
# | R_0 [0.1 nm]         |    0.551239 |
# | w_R [cm^-1]          |  251.924    |
# | th_R [rad]           |    3.31329  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2516.29      |
# | w2 [cm^-1]           | 1571         |
# | l [kcal/mol]         |    2.91298   |
# | x_eq [kcal/mol]      |   -8.45793   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.93869   |
# | R_eq [0.1 nm]        |    0.619661  |
# | R_0 [0.1 nm]         |    0.0990024 |
# | w_R [cm^-1]          |  119.254     |
# | th_R [rad]           |    1.83588   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3299.44     |
# | w2 [cm^-1]           | 3730.03     |
# | l [kcal/mol]         |    5.69375  |
# | x_eq [kcal/mol]      |   -0.102188 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.97459  |
# | R_eq [0.1 nm]        |    0.885527 |
# | R_0 [0.1 nm]         |    0.421194 |
# | w_R [cm^-1]          |  103.555    |
# | th_R [rad]           |    2.18157  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2346.03     |
# | w2 [cm^-1]           | 3600.75     |
# | l [kcal/mol]         |    0.801033 |
# | x_eq [kcal/mol]      |   -3.28151  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.79521  |
# | R_eq [0.1 nm]        |    0.671995 |
# | R_0 [0.1 nm]         |    0.174069 |
# | w_R [cm^-1]          |  106.832    |
# | th_R [rad]           |    3.77092  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1993.5      |
# | w2 [cm^-1]           | 1960.27     |
# | l [kcal/mol]         |    1.03952  |
# | x_eq [kcal/mol]      |   -4.41286  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.1981   |
# | R_eq [0.1 nm]        |    0.85536  |
# | R_0 [0.1 nm]         |    0.810201 |
# | w_R [cm^-1]          |  168.639    |
# | th_R [rad]           |    3.96863  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3069.34     |
# | w2 [cm^-1]           | 1551.95     |
# | l [kcal/mol]         |    7.22127  |
# | x_eq [kcal/mol]      |    6.19403  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.62524  |
# | R_eq [0.1 nm]        |    0.47522  |
# | R_0 [0.1 nm]         |    0.255016 |
# | w_R [cm^-1]          |  212.933    |
# | th_R [rad]           |    4.83201  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1767.63     |
# | w2 [cm^-1]           | 3306.92     |
# | l [kcal/mol]         |    8.77396  |
# | x_eq [kcal/mol]      |    3.69692  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.23442  |
# | R_eq [0.1 nm]        |    0.21516  |
# | R_0 [0.1 nm]         |    0.184519 |
# | w_R [cm^-1]          |  259.986    |
# | th_R [rad]           |    4.96382  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2353.06     |
# | w2 [cm^-1]           | 3836.2      |
# | l [kcal/mol]         |    7.61326  |
# | x_eq [kcal/mol]      |    2.8055   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.804747 |
# | R_eq [0.1 nm]        |    0.85224  |
# | R_0 [0.1 nm]         |    0.470449 |
# | w_R [cm^-1]          |  201.44     |
# | th_R [rad]           |    3.44006  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3051.43     |
# | w2 [cm^-1]           | 3826.96     |
# | l [kcal/mol]         |    9.84193  |
# | x_eq [kcal/mol]      |   -5.27604  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.83538  |
# | R_eq [0.1 nm]        |    0.634807 |
# | R_0 [0.1 nm]         |    0.291726 |
# | w_R [cm^-1]          |  270.027    |
# | th_R [rad]           |    0.488729 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# ...
# | w_R [cm^-1]          |  276.748    |
# | th_R [rad]           |    4.35515  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1580.21     |
# | w2 [cm^-1]           | 2516.2      |
# | l [kcal/mol]         |    4.20272  |
# | x_eq [kcal/mol]      |    5.02629  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.82989  |
# | R_eq [0.1 nm]        |    0.776323 |
# | R_0 [0.1 nm]         |    0.543401 |
# | w_R [cm^-1]          |  249.949    |
# | th_R [rad]           |    4.68092  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3733.24     |
# | w2 [cm^-1]           | 3346.51     |
# | l [kcal/mol]         |    8.1517   |
# | x_eq [kcal/mol]      |    9.94201  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.81677  |
# | R_eq [0.1 nm]        |    0.775795 |
# | R_0 [0.1 nm]         |    0.743592 |
# | w_R [cm^-1]          |  210.576    |
# | th_R [rad]           |    1.33345  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2702        |
# | w2 [cm^-1]           | 2917.57     |
# | l [kcal/mol]         |    8.54051  |
# | x_eq [kcal/mol]      |    0.581346 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.98915  |
# | R_eq [0.1 nm]        |    0.432656 |
# | R_0 [0.1 nm]         |    0.354722 |
# | w_R [cm^-1]          |  263.883    |
# | th_R [rad]           |    1.71398  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3434.91      |
# | w2 [cm^-1]           | 2320.43      |
# | l [kcal/mol]         |    2.50141   |
# | x_eq [kcal/mol]      |   -7.96656   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.65124   |
# | R_eq [0.1 nm]        |    0.591169  |
# | R_0 [0.1 nm]         |    0.0154069 |
# | w_R [cm^-1]          |  288.662     |
# | th_R [rad]           |    5.317     |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3609.26     |
# | w2 [cm^-1]           | 1886.81     |
# | l [kcal/mol]         |    5.37645  |
# | x_eq [kcal/mol]      |   -7.96048  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.5715   |
# | R_eq [0.1 nm]        |    0.882191 |
# | R_0 [0.1 nm]         |    0.807484 |
# | w_R [cm^-1]          |  291.837    |
# | th_R [rad]           |    5.10992  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2520.58     |
# | w2 [cm^-1]           | 3340.11     |
# | l [kcal/mol]         |    8.8805   |
# | x_eq [kcal/mol]      |   -8.46613  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.61189  |
# | R_eq [0.1 nm]        |    0.753449 |
# | R_0 [0.1 nm]         |    0.046545 |
# | w_R [cm^-1]          |  168.932    |
# | th_R [rad]           |    3.84937  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2056.89     |
# | w2 [cm^-1]           | 1930.11     |
# | l [kcal/mol]         |    2.0112   |
# | x_eq [kcal/mol]      |    5.74817  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.69516  |
# | R_eq [0.1 nm]        |    0.267872 |
# | R_0 [0.1 nm]         |    0.22779  |
# | w_R [cm^-1]          |  223.826    |
# | th_R [rad]           |    1.78642  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2575.89     |
# | w2 [cm^-1]           | 2414.21     |
# | l [kcal/mol]         |    8.17378  |
# | x_eq [kcal/mol]      |   -4.16026  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.81106  |
# | R_eq [0.1 nm]        |    0.227677 |
# | R_0 [0.1 nm]         |    0.138358 |
# | w_R [cm^-1]          |  217.062    |
# | th_R [rad]           |    4.27945  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2576.81     |
# | w2 [cm^-1]           | 3369.04     |
# | l [kcal/mol]         |    6.57214  |
# | x_eq [kcal/mol]      |   -7.96837  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.2058   |
# | R_eq [0.1 nm]        |    0.42251  |
# | R_0 [0.1 nm]         |    0.299996 |
# | w_R [cm^-1]          |  220.61     |
# | th_R [rad]           |    0.271165 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1822.89     |
# | w2 [cm^-1]           | 2630.83     |
# | l [kcal/mol]         |    7.30697  |
# | x_eq [kcal/mol]      |    4.2366   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.60963  |
# | R_eq [0.1 nm]        |    0.32914  |
# | R_0 [0.1 nm]         |    0.254369 |
# | w_R [cm^-1]          |  225.162    |
# | th_R [rad]           |    0.555611 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1919.36     |
# | w2 [cm^-1]           | 1678.28     |
# | l [kcal/mol]         |    7.47222  |
# | x_eq [kcal/mol]      |   -7.28931  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.13305  |
# | R_eq [0.1 nm]        |    0.663875 |
# | R_0 [0.1 nm]         |    0.395879 |
# | w_R [cm^-1]          |  221.22     |
# | th_R [rad]           |    5.26446  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3722.99     |
# | w2 [cm^-1]           | 3528.15     |
# | l [kcal/mol]         |    6.71975  |
# | x_eq [kcal/mol]      |   -2.98078  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.43683  |
# | R_eq [0.1 nm]        |    0.844167 |
# | R_0 [0.1 nm]         |    0.416017 |
# | w_R [cm^-1]          |  188.641    |
# | th_R [rad]           |    4.25466  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3442.25      |
# | w2 [cm^-1]           | 2969.99      |
# | l [kcal/mol]         |    0.290491  |
# | x_eq [kcal/mol]      |    8.02503   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.8025    |
# | R_eq [0.1 nm]        |    0.447183  |
# | R_0 [0.1 nm]         |    0.0412171 |
# | w_R [cm^-1]          |  267.06      |
# | th_R [rad]           |    2.84593   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2020.77     |
# | w2 [cm^-1]           | 1940.44     |
# | l [kcal/mol]         |    1.92391  |
# | x_eq [kcal/mol]      |   -3.10661  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.50253  |
# | R_eq [0.1 nm]        |    0.292342 |
# | R_0 [0.1 nm]         |    0.183624 |
# | w_R [cm^-1]          |  244.247    |
# | th_R [rad]           |    5.60089  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2145.57     |
# | w2 [cm^-1]           | 3383.47     |
# | l [kcal/mol]         |    7.26944  |
# | x_eq [kcal/mol]      |    6.2535   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.45276  |
# | R_eq [0.1 nm]        |    0.862208 |
# | R_0 [0.1 nm]         |    0.348179 |
# | w_R [cm^-1]          |  178.889    |
# | th_R [rad]           |    1.21668  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3106.33     |
# | w2 [cm^-1]           | 3329.62     |
# | l [kcal/mol]         |    1.64908  |
# | x_eq [kcal/mol]      |   -0.518294 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.18267  |
# | R_eq [0.1 nm]        |    0.605452 |
# | R_0 [0.1 nm]         |    0.352739 |
# | w_R [cm^-1]          |  247.683    |
# | th_R [rad]           |    4.99171  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3290.96     |
# | w2 [cm^-1]           | 3818.45     |
# | l [kcal/mol]         |    7.80212  |
# | x_eq [kcal/mol]      |   -9.75001  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.23362  |
# | R_eq [0.1 nm]        |    0.691305 |
# | R_0 [0.1 nm]         |    0.556528 |
# | w_R [cm^-1]          |  199.886    |
# | th_R [rad]           |    2.87857  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2659.29     |
# | w2 [cm^-1]           | 2055.25     |
# | l [kcal/mol]         |    6.02976  |
# | x_eq [kcal/mol]      |    5.79826  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.87238  |
# | R_eq [0.1 nm]        |    0.531795 |
# | R_0 [0.1 nm]         |    0.459957 |
# | w_R [cm^-1]          |  107.63     |
# | th_R [rad]           |    4.23504  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1718.44     |
# | w2 [cm^-1]           | 2027.9      |
# | l [kcal/mol]         |    5.18044  |
# | x_eq [kcal/mol]      |    4.45275  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.664802 |
# | R_eq [0.1 nm]        |    0.293776 |
# | R_0 [0.1 nm]         |    0.17942  |
# | w_R [cm^-1]          |  219.952    |
# | th_R [rad]           |    1.59214  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2847.05      |
# | w2 [cm^-1]           | 3533.95      |
# | l [kcal/mol]         |    2.92346   |
# | x_eq [kcal/mol]      |   -6.41264   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    4.00522   |
# | R_eq [0.1 nm]        |    0.424899  |
# | R_0 [0.1 nm]         |    0.0680915 |
# | w_R [cm^-1]          |  283.062     |
# | th_R [rad]           |    5.73206   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2131.65     |
# | w2 [cm^-1]           | 2011.03     |
# | l [kcal/mol]         |    5.39342  |
# | x_eq [kcal/mol]      |    8.50857  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.96404  |
# | R_eq [0.1 nm]        |    0.674785 |
# | R_0 [0.1 nm]         |    0.341784 |
# | w_R [cm^-1]          |  292.069    |
# | th_R [rad]           |    6.22333  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2888.3       |
# | w2 [cm^-1]           | 2773.12      |
# | l [kcal/mol]         |    0.114008  |
# | x_eq [kcal/mol]      |    4.88756   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.0393    |
# | R_eq [0.1 nm]        |    0.372256  |
# | R_0 [0.1 nm]         |    0.0454558 |
# | w_R [cm^-1]          |  274.507     |
# | th_R [rad]           |    3.68512   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1966.36     |
# | w2 [cm^-1]           | 1528.24     |
# | l [kcal/mol]         |    4.73854  |
# | x_eq [kcal/mol]      |   -2.64212  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.00084  |
# | R_eq [0.1 nm]        |    0.935313 |
# | R_0 [0.1 nm]         |    0.752728 |
# | w_R [cm^-1]          |  117.422    |
# | th_R [rad]           |    1.82241  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2490.61     |
# | w2 [cm^-1]           | 2615.48     |
# | l [kcal/mol]         |    4.44326  |
# | x_eq [kcal/mol]      |   -8.46415  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.73769  |
# | R_eq [0.1 nm]        |    0.868916 |
# | R_0 [0.1 nm]         |    0.419363 |
# | w_R [cm^-1]          |  158.322    |
# | th_R [rad]           |    0.500963 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3863.2      |
# | w2 [cm^-1]           | 1860.04     |
# | l [kcal/mol]         |    8.64906  |
# | x_eq [kcal/mol]      |   -8.3954   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.173558 |
# | R_eq [0.1 nm]        |    0.744778 |
# | R_0 [0.1 nm]         |    0.251732 |
# | w_R [cm^-1]          |  175.007    |
# | th_R [rad]           |    3.69768  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2734.48     |
# | w2 [cm^-1]           | 3682.49     |
# | l [kcal/mol]         |    3.3295   |
# | x_eq [kcal/mol]      |    3.94159  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.62114  |
# | R_eq [0.1 nm]        |    0.766493 |
# | R_0 [0.1 nm]         |    0.351795 |
# | w_R [cm^-1]          |  145.686    |
# | th_R [rad]           |    3.49119  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3833.16     |
# | w2 [cm^-1]           | 2781.27     |
# | l [kcal/mol]         |    5.76947  |
# | x_eq [kcal/mol]      |   -4.55696  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.20655  |
# | R_eq [0.1 nm]        |    0.332957 |
# | R_0 [0.1 nm]         |    0.234465 |
# | w_R [cm^-1]          |  121.006    |
# | th_R [rad]           |    2.38139  |
# | m (Proton mass [au]) | 1836        |
